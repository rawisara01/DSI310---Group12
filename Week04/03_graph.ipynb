# %% [markdown]
# # install extra library

# %%
pip install networkx
# Out:
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (2.8.5)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # read news SPO from DataPlatform

# %%
from dsmlibrary.datanode import DataNode
from tqdm.auto import tqdm

# %%
datanode = DataNode()
# Out:
# Init DataNode sucessful!

# %%
dir_process_id = 65

# %%
df = datanode.read_df(datanode.get_file_id(directory_id=dir_process_id, name="week04.parquet"))
df
# Out:
#                                              topic_acc date_published  \
# 0    สงขลา ปาดังเบซาร์-ท่าข่อย ถนนพังเป็นหลุมใหญ่ เ...   07 พ.ย. 2022
# 1    เพชรบูรณ์-ผญบ.ทับเบิกเบื่อทนฟัง 9 ปีอยู่ในเขตป...   02 พ.ย. 2022
# 2    อุบัติเหตุสยอง!! ปิคอัพชน จยย.พ่วงข้างอย่างจัง...   29 ต.ค. 2022
# 3    ลำปางรณรงค์ลดอุบัติเหตุทางข้ามเคร่งครัดบังคับใ...   26 ต.ค. 2022
# 4    นครนายก- (มีคลิป) อุบัติเหตุรถยนต์เสียหลักพุ่ง...   09 ต.ค. 2022
# ..                                                 ...            ...
# 105  เพชรบูรณ์-เกิดอุบัติเหตุซ้อน รถพยาบาลฉุกเฉิน ช...   14 ม.ค. 2022
# 106  ชายอายุราว 50 ปี เกิดอุบัติเหตุรถกระบะตกในร่อง...   14 ม.ค. 2022
# 107  (ชมคลิป) ยูเทิร์นวัดใจ เจ็บตายบ่อย เกิดอุบัติเ...   10 ม.ค. 2022
# 108  พลิกตะแคงหวิดดับ อุบัติเหตุรถยนต์ชนสนั่น 3 คัน...   09 ม.ค. 2022
# 109  เกิดอุบัติเหตุรถบรรทุกสารเคมีพลิกคว่ำที่ จ.ปรา...   07 ม.ค. 2022
#
#     province_acc                                        link_url
# 0          สงขลา  https://www.77kaoded.com/news/phumarin/2365601
# 1      เพชรบูรณ์  https://www.77kaoded.com/news/soontorn/2362961
# 2        สระแก้ว  https://www.77kaoded.com/news/thanapat/2361453
# 3          ลำปาง   https://www.77kaoded.com/news/prateep/2360276
# 4        นครนายก   https://www.77kaoded.com/news/ibaspea/2352400
# ..           ...                                             ...
# 105    เพชรบูรณ์  https://www.77kaoded.com/news/soontorn/2226908
# 106     เชียงราย       https://www.77kaoded.com/news/big/2226700
# 107     เชียงราย       https://www.77kaoded.com/news/big/2224781
# 108   ปราจีนบุรี  https://www.77kaoded.com/news/thanapat/2224141
# 109   ปราจีนบุรี  https://www.77kaoded.com/news/thanapat/2223027
#
# [110 rows x 4 columns]

# %% [markdown]
# # prepair graph data

# %%
graph_data = [(elm.get('TITLE'), elm.get('DATE')) for elm in df.to_dict('records')]
graph_data
# Out:
# [('สงขลา ปาดังเบซาร์-ท่าข่อย ถนนพังเป็นหลุมใหญ่ เกิดอุบัติเหตุหลายครั้ง หน่วยงานฯเมิน',
#   '07 พ.ย. 2022'),
#  ('เพชรบูรณ์-ผญบ.ทับเบิกเบื่อทนฟัง 9 ปีอยู่ในเขตป่า นำชาวบ้านเดินหน้าลุยซ่อมถนน โดยไม่ใช้งบฯราชการ หลังนทท.เกิดอุบัติเหตุบ่อย',
#   '02 พ.ย. 2022'),
#  ('อุบัติเหตุสยอง!! ปิคอัพชน จยย.พ่วงข้างอย่างจัง ร่างปลิวตกสะพานข้ามคลองพระสทึงจมดับ',
#   '29 ต.ค. 2022'),
#  ('ลำปางรณรงค์ลดอุบัติเหตุทางข้ามเคร่งครัดบังคับใช้กฎหมาย พ.ร.บ.จราจรทางบก',
#   '26 ต.ค. 2022'),
#  ('นครนายก- (มีคลิป) อุบัติเหตุรถยนต์เสียหลักพุ่งชนเสาไฟฟ้า ดับ 1 สาหัส 4 ราย เจ็บเล็กน้อย 1 ราย',
#   '09 ต.ค. 2022'),
#  ('ชาวบ้านวอนซ่อมถนนพัง ถนนสาย 304 หวิดเกิดอุบัติเหตุทุกวินาที',
#   '06 ต.ค. 2022'),
#  ('สงขลา ซ้ำซาก!!! อุบัติเหตุรถยนต์กระบะชนท้ายเทรลเลอร์ “อส.สะเดา”ดับพร้อมภรรยา',
#   '24 ก.ย. 2022'),
#  ('เมืองกาญจน์ Kick off สวมหมวกนิรภัย 100% รณรงค์สร้างจิตสำนึกลดอุบัติเหตุบนท้องถนน (ชมคลิป)',
#   '21 ก.ย. 2022'),
#  ('ตรังจัดป้องกันการเกิดอุบัติเหตุและรณรงค์สวมหมวกนิรภัย 100 เปอร์เซ็นต์',
#   '21 ก.ย. 2022'),
#  ('ชาวบ้านสุดจะทน!! ขนต้นไม้ปลูกกลางถนนสายหลัก หลังถนนพังเกิดอุบัติเหตุบ่อย จ.สระแก้ว',
#   '21 ก.ย. 2022'),
#  ('นครนายก-อุบัติเหตุรถเก๋งพุ่งชน รถจยย. คนขี่รถจยย. ลอยไปกระแทกเสาฟ้า ดับคาที่',
#   '14 ก.ย. 2022'),
#  ('อุบัติเหตุซ้ำซาก!! รถพ่วง 22 ล้อ บรรทุกไม้ไผ่พลิกคว่ำปิดทางขึ้น-ลง ช่องเขาตะโกเป็นอัมพาตเกือบครึ่งวัน',
#   '10 ก.ย. 2022'),
#  ('สระแก้ว ฝนตกหนักถนนลื่นเกิดอุบัติเหตุกระบะเสียหลักพลิกคว่ำชนเสาไฟฟ้าดับ 1 ราย',
#   '08 ก.ย. 2022'),
#  ('รณรงค์เพื่อลดอุบัติเหตุบริเวณทางข้าม', '21 ส.ค. 2022'),
#  ('รพ.ลำปาง เปิดศูนย์อุบัติเหตุฉุกเฉินอัจฉริยะและหอผู้ป่วยวิกฤต เสริมประสิทธิภาพด้านการรักษา',
#   '20 ส.ค. 2022'),
#  ('ผอ.สถาบันฯ ปิดทองหลังพระฯ ประสบอุบัติเหตุเสียชีวิต ที่เพชรบุรี',
#   '18 ส.ค. 2022'),
#  ('ตายอีก 1 ราย อุบัติเหตุหมู่นักเรียนขับปิกอัพพลิกคว่ำชนเสาไฟฟ้า จ.สระแก้ว',
#   '18 ส.ค. 2022'),
#  ('ลำพูน การนิคมฯนำพนักงาน ผู้ประกอบการและประชาชน อบรมสร้างวินัยจราจรลดอุบัติเหตุและการเสียชีวิต',
#   '15 ส.ค. 2022'),
#  ('มอบโลงศพบริจาคช่วยนักเรียนที่ประสบอุบัติเหตุหมู่ แม่เผยหัวใจแทบสลาย มีลูกแค่คนเดียว ไม่อยากให้เด็กเอารถยนต์มาใช้กันเองแบบนี้',
#   '13 ส.ค. 2022'),
#  ('นายอำเภอธาตุพนม มอบสินไหมให้ทายาทผู้ประสบอุบัติเหตุ 8 ราย', '04 ส.ค. 2022'),
#  ('บรรทุกหนัก!! อุบัติเหตุ 10 ล้อ หัวพ่วงขาดกระเด็นข้ามเลนชนกันสนั่นพังยับ พระเจ็บ 3 ราย รถติดระนาว',
#   '03 ส.ค. 2022'),
#  ('คณะกรรมการสอบสวนอุบัติเหตุและอุบัติการณ์ของอากาศยาน (กสอ.)ได้อนุญาตให้มีการเคลื่อนย้ายอากาศยาน',
#   '02 ส.ค. 2022'),
#  ('นครนายก-อุบัติเหตุรถพ่วงพุ่งชนรถ 6 ล้อกับรถกระบะ 2 คันรวด', '01 ส.ค. 2022'),
#  ('สลดรถทัวร์ นทท.ชาวไทยเกิดอุบัติเหตุที่ลาวเสียชีวิต 5 ราย 2 รายเป็นชาวขอนแก่น',
#   '01 ส.ค. 2022'),
#  ('อันตรายสายเคเบิ้ลเกลื่อนพื้นถนนจนทำให้เกิดอุบัติเหตุเกี่ยวรถจักรยานยนต์',
#   '27 ก.ค. 2022'),
#  ('สุดสลด “กอล์ฟ กิ๊ฟช็อป”หนุ่มพิการสู้ชีวิตประสบอุบัติเหตุเสียชีวิต',
#   '26 ก.ค. 2022'),
#  ('เตือนภัย จุดตัดถนนทางรถไฟ สุดอันตราย อุบัติเหตุซ้ำซาก วอนหน่วยงานรับผิดชอบแก้ไขด่วน',
#   '26 ก.ค. 2022'),
#  ('หนุ่มโวย !!! แท่งแบริเออร์ไม่มีอะไรใส่ถ่วงน้ำหนักรถเยียบปลิวว่อน ทำรถ จยย.วิ่งทับเกิดอุบัติเหตุ',
#   '22 ก.ค. 2022'),
#  ('ฝนตกในพื้นที่ภูเก็ต จักรยานยนต์เกิดอุบัติเหตุหลายราย นายกราไวย์เตือนขับขี่ระมัดระวัง',
#   '21 ก.ค. 2022'),
#  ('ชาวบ้านโวยกรมทางหลวงสร้างทาง 4 ช่องจราจร มีการปลูกหญ้าข้างแท่งคอนกรีตเกาะกลางถนนทำให้เสี่ยงเกิดอุบัติเหตุ\xa0',
#   '20 ก.ค. 2022'),
#  ('พัทลุง-อุบัติเหตุซ้ำเฮลิคอปเตอร์แบล็กฮอว์กคณะของแม่ทัพภาค 4 ขณะขนย้าย ไปที่ จ.ลพบุรี เพื่อพิสูจน์หาสาเหตุ',
#   '18 ก.ค. 2022'),
#  ('ปราจีนบุรี อุบัติเหตุกระบะเสียหลักชนคอสะพานหวิดดับยกครัว', '18 ก.ค. 2022'),
#  ('สงขลา ด่วน !!! อุบัติเหตุ ฮ.เเม่ทัพภาค 4 ตกกลางสวนยาง โชคดีแค่บาดเจ็บ',
#   '15 ก.ค. 2022'),
#  ('ขอนแก่นตั้งศูนย์ปฏิบัติการป้องกันและลดอุบัติเหตุทางถนนช่วงเทศกาลหยุดยาว 13 -17 ก.ค. 2565',
#   '12 ก.ค. 2022'),
#  ('อุบัติเหตุสลดคร่าชีวิต สจ.คนดัง 2 สมัย', '06 ก.ค. 2022'),
#  ('ผู้รับเหมา ปรับปรุงผิวจราจร กลางคืนไร้แสงไฟ เกิดอุบัติเหตุบ่อยครั้งจนทำให้ปู่วัย 81 ปีเสียชีวิต',
#   '16 มิ.ย. 2022'),
#  ('ยิงกันในงานบวชที่เพชรบุรี คนยิงหนีไปเกิดอุบัติเหตุจนปืนตก แต่ก็ยังขับรถหนีไปได้',
#   '12 มิ.ย. 2022'),
#  ('อุบัติเหตุสลดรับอุรณ รถตู้โดยสารชนชายนุ่งขาวเสียชีวิตคาที่',
#   '11 มิ.ย. 2022'),
#  ('เกิดอุบัติเหตุยางรถไถระเบิดใส่หน้าเสียชีวิตคาที่ จ.สระแก้ว',
#   '04 มิ.ย. 2022'),
#  ('“นครพนมมีแต่คนน่ารัก” ผจก.ร้านเหล้าเผย ลูกค้าเมากลัวอุบัติเหตุเปิดพัดลมให้นอน',
#   '31 พ.ค. 2022'),
#  ('(คลิป) มือดีโทรแจ้งตร.ตรัง มีอุบัติเหตุใหญ่ จนท.-นักข่าว บึ่งรถไม่แคร์น้ำมันแพง แต่พบแค่ความว่างเปล่า',
#   '30 พ.ค. 2022'),
#  ('ปทุมธานี เดินหน้ารณรงค์ “ลดอุบัติเหตุบริเวณทางข้ามและสวมหมวกนิรภัย 100 %” มุ่งสร้างวินัยจราจร',
#   '23 พ.ค. 2022'),
#  ('นายอำเภอเมืองลพบุรีห่วงใยประชาชนนำรณรงค์การลดอุบัติเหตุทางถนน',
#   '20 พ.ค. 2022'),
#  ('สงขลา รถตำรวจ สภ.ตะโหมด ประสบอุบัติเหตุชนราวสะพาน โชคดีแค่บาดเจ็บ',
#   '16 พ.ค. 2022'),
#  ('ตำรวจนครนายกตรวจเข้มหยุดยาว 4 วัน หวั่นเกิดอุบัติเหตุ และอาชญากรรม',
#   '14 พ.ค. 2022'),
#  ('อุบัติเหตุสลด!! กระบะยางแตกพลิกคว่ำ เด็กหญิง 1 ขวบครึ่งดับ',
#   '08 พ.ค. 2022'),
#  ('พุ่งชนจังจัง!! กล้องหน้ารถจับภาพชัด อุบัติเหตุลุงขับรถ จยย.หลุดโค้ง เสยรถเก๋งดับคาที่',
#   '07 พ.ค. 2022'),
#  ('โคราช!!! ยึดยาบ้า 8 ล้านเม็ด หลังได้รับแจ้งว่ามีอุบัติเหตุ',
#   '02 พ.ค. 2022'),
#  ('ญาติร่ำไห้ลั่น!! ถนนสุดอันตราย ร้องเรียนอุบัติเหตุซ้ำซาก ขูดถนนทำใหม่ จยย.เสียหลักถูกพ่วง 22 ล้อ ทับหัวตายคาที่',
#   '29 เม.ย. 2022'),
#  ('อุบัติเหตุ รถบรรทุกตู้คอนเทนเนอร์ เสียหลัก ทำตู้ฯหล่นบนถนน โชคดีไร้ผู้บาดเจ็บ',
#   '23 เม.ย. 2022'),
#  ('ผู้สมัครนายกเมืองพัทยา หมายเลข 2 ช่วยเหลือประชาชนประสบอุบัติเหตุ',
#   '18 เม.ย. 2022'),
#  ('ฝนตกหนักเกิดอุบัติเหตุรถกระบะชนรถกระบะ เสียชีวิตคาที่ 1 บาดเจ็บอีก 1',
#   '18 เม.ย. 2022'),
#  ('ครอบครัวร้องขอความเป็นธรรม ลูกตาย 3 ปี คดีไม่คืบ-ไม่เชื่อเป็นอุบัติเหตุ',
#   '18 เม.ย. 2022'),
#  ('กระบี่-วันที่ 6 ช่วงสงกรานต์ มีอุบัติเหตุสะสม 28 ครั้งเสียชีวิต 2 ราย',
#   '17 เม.ย. 2022'),
#  ('อุบัติเหตุสระแก้ว 6 วันตาย 7 ศพ แห่เดินทางกลับวันสุดท้าย', '17 เม.ย. 2022'),
#  ('กระบี่-วันที่สี่ช่วงสงกรานต์ มีอุบัติเหตุสะสมตายแล้ว 2 ราย',
#   '15 เม.ย. 2022'),
#  ('นครฯ – 3 วันสงกรานต์เมืองคอน เกิดอุบัติเหตุ 33 ครั้ง (สูงสุดของประเทศ) ตาย 1 เจ็บ 36 คน',
#   '14 เม.ย. 2022'),
#  ('อุบัติเหตุเซ่นสงกรานต์ 7 วันอันตราย เสียชีวิต 2 ศพ จ.สระแก้ว',
#   '14 เม.ย. 2022'),
#  ('กระบี่-วันที่สามช่วงสงกรานต์ มีอุบัติเหตุสะสมแล้ว 10 ครั้ง',
#   '14 เม.ย. 2022'),
#  ('กระบี่-วันที่สองช่วงสงกรานต์ มีอุบัติเหตุสะสมแล้ว 5 ครั้ง',
#   '13 เม.ย. 2022'),
#  ('พัทลุง-ศูนย์อุบัติเหตุในช่วง 7 วันอันตราย เทศกาลสงกรานต์ สรุปผลวันแรก 2 ศพ -77ข่าวเด็ด',
#   '12 เม.ย. 2022'),
#  ('เพชรบูรณ์-อุบัติเหตุดับรายแรก เซ่น 7 วันอันตรายช่วงสงกรานต์',
#   '12 เม.ย. 2022'),
#  ('กระบี่-7 วันแรกช่วงสงกรานต์ มีอุบัติเหตุแล้ว 2 ครั้ง', '12 เม.ย. 2022'),
#  ('ชาวบ้านร้องขอสัณญานไฟจราจร หวังลดอุบัติเหตุและไม่ต้องไปกลับรถไกล',
#   '11 เม.ย. 2022'),
#  ('ผู้ว่าพังงาปล่อยขบวนรณรงค์ 7 วันอันตรายคุมเข้มลดอุบัติเหตุทางถนนช่วงเทศกาลสงกรานต์ 2565',
#   '11 เม.ย. 2022'),
#  ('น่าน เปิดศูนย์ป้องกันอุบัติเหตุช่วงสงกรานต์', '11 เม.ย. 2022'),
#  ('กระบี่-เปิดศูนย์ปฏิบัติการร่วมป้องกันและลดอุบัติเหตุทางถนนและทางทะเลช่วงเทศกาลสงกรานต์ (มีคลิป)',
#   '11 เม.ย. 2022'),
#  ('ลำปาง เปิดศูนย์รณรงค์ลดอุบัติเหตุทางถนนเฝ้าระวังโควิด-19ช่วงสงกรานต์',
#   '11 เม.ย. 2022'),
#  ('ชัยภูมิเร่งเปิดหอผู้ป่วยช่วงสงกรานต์รองรับแยกผู้ป่วยเพิ่มทั้งอุบัติเหตุ-โควิดยังพุ่ง!',
#   '11 เม.ย. 2022'),
#  ('สกัดจยย.แต่งซิ่ง ป้องกันอุบัติเหตุ 7 วัน อันตราย', '11 เม.ย. 2022'),
#  ('ตำรวจช่าง สภ.สระบัว ช่วยซ่อมแซมถนนพัง เพื่อลดอุบัติเหตุช่วงเทศกาลสงกรานต์',
#   '08 เม.ย. 2022'),
#  ('ซ้อมแผนอุบัติเหตุหมู่รับเทศกาลสงกรานต์ จ.สระแก้ว', '07 เม.ย. 2022'),
#  ('ระนองเปิดศูนย์ปฏิบัติการร่วมป้องกันและลดอุบัติเหตุทางถนนช่วงเทศกาลสงกรานต์',
#   '07 เม.ย. 2022'),
#  ('ตร.มหาชัย ตั้งด่านแจกหมวกกันน็อก รณรงค์ลดอุบัติเหตุสงกรานต์',
#   '07 เม.ย. 2022'),
#  ('สภ เมืองพัทยา เตรียมความพร้อมป้องกันอุบัติเหตุบนถนน', '07 เม.ย. 2022'),
#  ('AIS มอบประกันอุบัติเหตุฟรี ต้อนรับสงกรานต์ 65', '07 เม.ย. 2022'),
#  ('นครนายก-อุบัติเหตุ รถกระบะชนกับรถกระบะ คู่กรณีหลบหนี (มีคลิป)',
#   '26 มี.ค. 2022'),
#  ('พังงา-ไฮโซปลาวาฬ\u200b ซิ่งเก๋งหรูเบนท์ลี่ย์ราคา\u200bกว่า 30 ล้าน เกิดอุบัติเหตุ\u200bไฟไหม้วอดทั้งคัน\u200b\xa0\xa0\xa0\xa0',
#   '25 มี.ค. 2022'),
#  ('“คลองขลุง” จัดกิจกรรมรณรงค์ปลอดภัยทางข้าม ไร้อุบัติเหตุจุดจราจรหนาแน่น',
#   '23 มี.ค. 2022'),
#  ('คืนสลด อุบัติเหตุสองราย ตาย 3 ศพ', '20 มี.ค. 2022'),
#  ('ระนอง รับนโยบาย เสริมสร้างประสิทธิภาพการป้องกันและลดอุบัติเหตุทางถนน',
#   '16 มี.ค. 2022'),
#  ('เครื่องบินเอฟ 16 ทอ. ประสบอุบัติเหตุระหว่างฝึกบิน นักบินปลอดภัย',
#   '08 มี.ค. 2022'),
#  ('เจ้าของคลิป เผยน้องใส่หน้ากากผีเป็นออทิสติกชอบแกล้งคนไม่มีอะไร แต่ก็เป็นห่วงกลัวเกิดอุบัติเหตุ',
#   '07 มี.ค. 2022'),
#  ('นายกเทศมนตรีนครรังสิตปรับปรุงทางม้าลายลดอุบัติเหตุหน้าโรงเรียน',
#   '27 ก.พ. 2022'),
#  ('ชื่นชม ครอบครัวหนุ่มประสบอุบัติเหตุ บริจาคหัวใจต่อลมหายใจผู้ป่วย',
#   '25 ก.พ. 2022'),
#  ('ปทุมธานี รณรงค์ลดอุบัติเหตุบริเวณทางข้าม ปรับปรุงทาสีใหม่ให้มีความเด่นชัด สร้างความปลอดภัยทางถนน',
#   '23 ก.พ. 2022'),
#  ('สมุทรสาคร รณรงค์ผู้ขับขี่หยุดให้คนข้ามทางม้าลาย ลดอุบัติเหตุ',
#   '22 ก.พ. 2022'),
#  ('กาฬสินธุ์รณรงค์ลดอุบัติเหตุบริเวณทางข้าม', '22 ก.พ. 2022'),
#  ('ระนองเปิดกิจกรรม “พาน้องข้ามถนน” เริ่มสัปดาห์รณรงค์เพื่อลดอุบัติเหตุทางข้าม',
#   '21 ก.พ. 2022'),
#  ('ลำปาง Kick off รณรงค์ลดอุบัติเหตุบริเวณทางข้าม สร้างจิตสำนึกการใช้รถใช้ถนน',
#   '21 ก.พ. 2022'),
#  ('แม่-ลูก จยย.ล้มทับแม่ช่วยเหลือตัวเองไม่ได้ ช่วงเวลาเร่งด่วนหวั่นอุบัติเหตุซ้ำ ชาวบ้านประสานกู้ภัยช่วย',
#   '19 ก.พ. 2022'),
#  ('อุบัติเหตุหนุ่มใหญ่พ่อค้าขายของประจำโรงงาน รถเสียหลักหลุดโค้งหวิดสิ้นชื่อ',
#   '13 ก.พ. 2022'),
#  ('อุบัติเหตุรถเก๋งเบรกไม่ทัน ชนท้ายรถบรรทุกไข่พลิกคว่ำไข่กระจายเสียหายทั้งคัน',
#   '11 ก.พ. 2022'),
#  ('อุบัติเหตุรถเฉี่ยวชนนักเรียนได้รับบาดเจ็บ จ.ปราจีนบุรี', '09 ก.พ. 2022'),
#  ('ทม.หัวหิน ทาสีทางม้าลายแบบใหม่สีขาว-แดง เห็นเด่นชัด ป้องกันอุบัติเหตุ',
#   '08 ก.พ. 2022'),
#  ('ประมูลทะเบียนเลขสวย จ.สระแก้ว นํารายได้ช่วยเหลือผู้พิการจากอุบัติเหตุและการใช้รถใช้ถนนไม่คึกคัก',
#   '05 ก.พ. 2022'),
#  ('สาวร้องเสียงหลงรถพ่วงบรรทุกไม้ซิ่งแหวกเลนขวาไม้ตกใส่รถหวิดเกิดอุบัติเหตุ',
#   '04 ก.พ. 2022'),
#  ('ปทุมธานี ซ้อมใหญ่แผนป้องกันอุบัติเหตุทางม้าลาย สมจริงจนประชาชนตกใจต้องหยุดรถดู',
#   '01 ก.พ. 2022'),
#  ('อุบัติเหตุรถยนต์เสียหลักตกถนนรับวันตรุษจีน จ.ปราจีนบุรี', '01 ก.พ. 2022'),
#  ('ตำรวจภูธรภาค 3 มอบโล่ประกาศเกียรติคุณ ให้แก่ ภาคีเครือข่ายและหน่วยงานในสังกัดที่มีผลการปฏิบัติงานดีเด่น ด้านการ ป้องกันและลดอุบัติเหตุทางถนน ในห้วงเทศกาลปีใหม่ พ.ศ.2565',
#   '26 ม.ค. 2022'),
#  ('ลำปางเร่งปรับปรุงทาสีเส้นทางม้าลายจุดเสี่ยง หวังลดอุบัติเหตุทางถนน',
#   '25 ม.ค. 2022'),
#  ('คุณยายวัย 67 ปีเช้าบวชลูกชาย บ่ายหลานชายประสบอุบัติเหตุเสียชีวิต เช้าวันรุ่งขึ้นคุณยายตรอมใจดับตาม',
#   '21 ม.ค. 2022'),
#  ('ถึงฤดูกาลลื่นไถล อุบัติเหตุระดมคว่ำยามเช้าต่อเนื่องบนทางสายเดิมที่แก้ไม่ตก',
#   '21 ม.ค. 2022'),
#  ('ดวงถึงฆาต!! “นายกคิงส์” ทรงยศ เทียนทอง อดีตนายก อบจ.สระแก้ว ถูกรถชนเสียชีวิตหลังรถเกิดอุบัติเหตุ',
#   '20 ม.ค. 2022'),
#  ('อุบัติเหตุรถพ่วง 18 ล้อ ซิ่งฝ่าไฟแดงชน 10 ล้อ สนั่นแยกสระขวัญหลายคัน',
#   '16 ม.ค. 2022'),
#  ('เพชรบูรณ์-เกิดอุบัติเหตุซ้อน รถพยาบาลฉุกเฉิน ชนรถสายตรวจตร. กลางแยกยูเทิร์น เจ็บระนาว 7 ราย (ชมคลิป)',
#   '14 ม.ค. 2022'),
#  ('ชายอายุราว 50 ปี เกิดอุบัติเหตุรถกระบะตกในร่องถนน ติดอยู่ในรถออกไม่ได้',
#   '14 ม.ค. 2022'),
#  ('(ชมคลิป) ยูเทิร์นวัดใจ เจ็บตายบ่อย เกิดอุบัติเหตุอีกแล้ว\xa0',
#   '10 ม.ค. 2022'),
#  ('พลิกตะแคงหวิดดับ อุบัติเหตุรถยนต์ชนสนั่น 3 คัน พังยับ', '09 ม.ค. 2022'),
#  ('เกิดอุบัติเหตุรถบรรทุกสารเคมีพลิกคว่ำที่ จ.ปราจีนบุรี', '07 ม.ค. 2022')]

# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt

from bokeh.io import output_notebook, show, save
from bokeh.models import Range1d, Circle, ColumnDataSource, MultiLine
from bokeh.plotting import figure
from bokeh.plotting import from_networkx

# %%
output_notebook()
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
news_titles = {elm:'name' for elm in list(df['TITLE'].unique())}
news_titles
# Out:
# {'สงขลา ปาดังเบซาร์-ท่าข่อย ถนนพังเป็นหลุมใหญ่ เกิดอุบัติเหตุหลายครั้ง หน่วยงานฯเมิน': 'name',
#  'เพชรบูรณ์-ผญบ.ทับเบิกเบื่อทนฟัง 9 ปีอยู่ในเขตป่า นำชาวบ้านเดินหน้าลุยซ่อมถนน โดยไม่ใช้งบฯราชการ หลังนทท.เกิดอุบัติเหตุบ่อย': 'name',
#  'อุบัติเหตุสยอง!! ปิคอัพชน จยย.พ่วงข้างอย่างจัง ร่างปลิวตกสะพานข้ามคลองพระสทึงจมดับ': 'name',
#  'ลำปางรณรงค์ลดอุบัติเหตุทางข้ามเคร่งครัดบังคับใช้กฎหมาย พ.ร.บ.จราจรทางบก': 'name',
#  'นครนายก- (มีคลิป) อุบัติเหตุรถยนต์เสียหลักพุ่งชนเสาไฟฟ้า ดับ 1 สาหัส 4 ราย เจ็บเล็กน้อย 1 ราย': 'name',
#  'ชาวบ้านวอนซ่อมถนนพัง ถนนสาย 304 หวิดเกิดอุบัติเหตุทุกวินาที': 'name',
#  'สงขลา ซ้ำซาก!!! อุบัติเหตุรถยนต์กระบะชนท้ายเทรลเลอร์ “อส.สะเดา”ดับพร้อมภรรยา': 'name',
#  'เมืองกาญจน์ Kick off สวมหมวกนิรภัย 100% รณรงค์สร้างจิตสำนึกลดอุบัติเหตุบนท้องถนน (ชมคลิป)': 'name',
#  'ตรังจัดป้องกันการเกิดอุบัติเหตุและรณรงค์สวมหมวกนิรภัย 100 เปอร์เซ็นต์': 'name',
#  'ชาวบ้านสุดจะทน!! ขนต้นไม้ปลูกกลางถนนสายหลัก หลังถนนพังเกิดอุบัติเหตุบ่อย จ.สระแก้ว': 'name',
#  'นครนายก-อุบัติเหตุรถเก๋งพุ่งชน รถจยย. คนขี่รถจยย. ลอยไปกระแทกเสาฟ้า ดับคาที่': 'name',
#  'อุบัติเหตุซ้ำซาก!! รถพ่วง 22 ล้อ บรรทุกไม้ไผ่พลิกคว่ำปิดทางขึ้น-ลง ช่องเขาตะโกเป็นอัมพาตเกือบครึ่งวัน': 'name',
#  'สระแก้ว ฝนตกหนักถนนลื่นเกิดอุบัติเหตุกระบะเสียหลักพลิกคว่ำชนเสาไฟฟ้าดับ 1 ราย': 'name',
#  'รณรงค์เพื่อลดอุบัติเหตุบริเวณทางข้าม': 'name',
#  'รพ.ลำปาง เปิดศูนย์อุบัติเหตุฉุกเฉินอัจฉริยะและหอผู้ป่วยวิกฤต เสริมประสิทธิภาพด้านการรักษา': 'name',
#  'ผอ.สถาบันฯ ปิดทองหลังพระฯ ประสบอุบัติเหตุเสียชีวิต ที่เพชรบุรี': 'name',
#  'ตายอีก 1 ราย อุบัติเหตุหมู่นักเรียนขับปิกอัพพลิกคว่ำชนเสาไฟฟ้า จ.สระแก้ว': 'name',
#  'ลำพูน การนิคมฯนำพนักงาน ผู้ประกอบการและประชาชน อบรมสร้างวินัยจราจรลดอุบัติเหตุและการเสียชีวิต': 'name',
#  'มอบโลงศพบริจาคช่วยนักเรียนที่ประสบอุบัติเหตุหมู่ แม่เผยหัวใจแทบสลาย มีลูกแค่คนเดียว ไม่อยากให้เด็กเอารถยนต์มาใช้กันเองแบบนี้': 'name',
#  'นายอำเภอธาตุพนม มอบสินไหมให้ทายาทผู้ประสบอุบัติเหตุ 8 ราย': 'name',
#  'บรรทุกหนัก!! อุบัติเหตุ 10 ล้อ หัวพ่วงขาดกระเด็นข้ามเลนชนกันสนั่นพังยับ พระเจ็บ 3 ราย รถติดระนาว': 'name',
#  'คณะกรรมการสอบสวนอุบัติเหตุและอุบัติการณ์ของอากาศยาน (กสอ.)ได้อนุญาตให้มีการเคลื่อนย้ายอากาศยาน': 'name',
#  'นครนายก-อุบัติเหตุรถพ่วงพุ่งชนรถ 6 ล้อกับรถกระบะ 2 คันรวด': 'name',
#  'สลดรถทัวร์ นทท.ชาวไทยเกิดอุบัติเหตุที่ลาวเสียชีวิต 5 ราย 2 รายเป็นชาวขอนแก่น': 'name',
#  'อันตรายสายเคเบิ้ลเกลื่อนพื้นถนนจนทำให้เกิดอุบัติเหตุเกี่ยวรถจักรยานยนต์': 'name',
#  'สุดสลด “กอล์ฟ กิ๊ฟช็อป”หนุ่มพิการสู้ชีวิตประสบอุบัติเหตุเสียชีวิต': 'name',
#  'เตือนภัย จุดตัดถนนทางรถไฟ สุดอันตราย อุบัติเหตุซ้ำซาก วอนหน่วยงานรับผิดชอบแก้ไขด่วน': 'name',
#  'หนุ่มโวย !!! แท่งแบริเออร์ไม่มีอะไรใส่ถ่วงน้ำหนักรถเยียบปลิวว่อน ทำรถ จยย.วิ่งทับเกิดอุบัติเหตุ': 'name',
#  'ฝนตกในพื้นที่ภูเก็ต จักรยานยนต์เกิดอุบัติเหตุหลายราย นายกราไวย์เตือนขับขี่ระมัดระวัง': 'name',
#  'ชาวบ้านโวยกรมทางหลวงสร้างทาง 4 ช่องจราจร มีการปลูกหญ้าข้างแท่งคอนกรีตเกาะกลางถนนทำให้เสี่ยงเกิดอุบัติเหตุ\xa0': 'name',
#  'พัทลุง-อุบัติเหตุซ้ำเฮลิคอปเตอร์แบล็กฮอว์กคณะของแม่ทัพภาค 4 ขณะขนย้าย ไปที่ จ.ลพบุรี เพื่อพิสูจน์หาสาเหตุ': 'name',
#  'ปราจีนบุรี อุบัติเหตุกระบะเสียหลักชนคอสะพานหวิดดับยกครัว': 'name',
#  'สงขลา ด่วน !!! อุบัติเหตุ ฮ.เเม่ทัพภาค 4 ตกกลางสวนยาง โชคดีแค่บาดเจ็บ': 'name',
#  'ขอนแก่นตั้งศูนย์ปฏิบัติการป้องกันและลดอุบัติเหตุทางถนนช่วงเทศกาลหยุดยาว 13 -17 ก.ค. 2565': 'name',
#  'อุบัติเหตุสลดคร่าชีวิต สจ.คนดัง 2 สมัย': 'name',
#  'ผู้รับเหมา ปรับปรุงผิวจราจร กลางคืนไร้แสงไฟ เกิดอุบัติเหตุบ่อยครั้งจนทำให้ปู่วัย 81 ปีเสียชีวิต': 'name',
#  'ยิงกันในงานบวชที่เพชรบุรี คนยิงหนีไปเกิดอุบัติเหตุจนปืนตก แต่ก็ยังขับรถหนีไปได้': 'name',
#  'อุบัติเหตุสลดรับอุรณ รถตู้โดยสารชนชายนุ่งขาวเสียชีวิตคาที่': 'name',
#  'เกิดอุบัติเหตุยางรถไถระเบิดใส่หน้าเสียชีวิตคาที่ จ.สระแก้ว': 'name',
#  '“นครพนมมีแต่คนน่ารัก” ผจก.ร้านเหล้าเผย ลูกค้าเมากลัวอุบัติเหตุเปิดพัดลมให้นอน': 'name',
#  '(คลิป) มือดีโทรแจ้งตร.ตรัง มีอุบัติเหตุใหญ่ จนท.-นักข่าว บึ่งรถไม่แคร์น้ำมันแพง แต่พบแค่ความว่างเปล่า': 'name',
#  'ปทุมธานี เดินหน้ารณรงค์ “ลดอุบัติเหตุบริเวณทางข้ามและสวมหมวกนิรภัย 100 %” มุ่งสร้างวินัยจราจร': 'name',
#  'นายอำเภอเมืองลพบุรีห่วงใยประชาชนนำรณรงค์การลดอุบัติเหตุทางถนน': 'name',
#  'สงขลา รถตำรวจ สภ.ตะโหมด ประสบอุบัติเหตุชนราวสะพาน โชคดีแค่บาดเจ็บ': 'name',
#  'ตำรวจนครนายกตรวจเข้มหยุดยาว 4 วัน หวั่นเกิดอุบัติเหตุ และอาชญากรรม': 'name',
#  'อุบัติเหตุสลด!! กระบะยางแตกพลิกคว่ำ เด็กหญิง 1 ขวบครึ่งดับ': 'name',
#  'พุ่งชนจังจัง!! กล้องหน้ารถจับภาพชัด อุบัติเหตุลุงขับรถ จยย.หลุดโค้ง เสยรถเก๋งดับคาที่': 'name',
#  'โคราช!!! ยึดยาบ้า 8 ล้านเม็ด หลังได้รับแจ้งว่ามีอุบัติเหตุ': 'name',
#  'ญาติร่ำไห้ลั่น!! ถนนสุดอันตราย ร้องเรียนอุบัติเหตุซ้ำซาก ขูดถนนทำใหม่ จยย.เสียหลักถูกพ่วง 22 ล้อ ทับหัวตายคาที่': 'name',
#  'อุบัติเหตุ รถบรรทุกตู้คอนเทนเนอร์ เสียหลัก ทำตู้ฯหล่นบนถนน โชคดีไร้ผู้บาดเจ็บ': 'name',
#  'ผู้สมัครนายกเมืองพัทยา หมายเลข 2 ช่วยเหลือประชาชนประสบอุบัติเหตุ': 'name',
#  'ฝนตกหนักเกิดอุบัติเหตุรถกระบะชนรถกระบะ เสียชีวิตคาที่ 1 บาดเจ็บอีก 1': 'name',
#  'ครอบครัวร้องขอความเป็นธรรม ลูกตาย 3 ปี คดีไม่คืบ-ไม่เชื่อเป็นอุบัติเหตุ': 'name',
#  'กระบี่-วันที่ 6 ช่วงสงกรานต์ มีอุบัติเหตุสะสม 28 ครั้งเสียชีวิต 2 ราย': 'name',
#  'อุบัติเหตุสระแก้ว 6 วันตาย 7 ศพ แห่เดินทางกลับวันสุดท้าย': 'name',
#  'กระบี่-วันที่สี่ช่วงสงกรานต์ มีอุบัติเหตุสะสมตายแล้ว 2 ราย': 'name',
#  'นครฯ – 3 วันสงกรานต์เมืองคอน เกิดอุบัติเหตุ 33 ครั้ง (สูงสุดของประเทศ) ตาย 1 เจ็บ 36 คน': 'name',
#  'อุบัติเหตุเซ่นสงกรานต์ 7 วันอันตราย เสียชีวิต 2 ศพ จ.สระแก้ว': 'name',
#  'กระบี่-วันที่สามช่วงสงกรานต์ มีอุบัติเหตุสะสมแล้ว 10 ครั้ง': 'name',
#  'กระบี่-วันที่สองช่วงสงกรานต์ มีอุบัติเหตุสะสมแล้ว 5 ครั้ง': 'name',
#  'พัทลุง-ศูนย์อุบัติเหตุในช่วง 7 วันอันตราย เทศกาลสงกรานต์ สรุปผลวันแรก 2 ศพ -77ข่าวเด็ด': 'name',
#  'เพชรบูรณ์-อุบัติเหตุดับรายแรก เซ่น 7 วันอันตรายช่วงสงกรานต์': 'name',
#  'กระบี่-7 วันแรกช่วงสงกรานต์ มีอุบัติเหตุแล้ว 2 ครั้ง': 'name',
#  'ชาวบ้านร้องขอสัณญานไฟจราจร หวังลดอุบัติเหตุและไม่ต้องไปกลับรถไกล': 'name',
#  'ผู้ว่าพังงาปล่อยขบวนรณรงค์ 7 วันอันตรายคุมเข้มลดอุบัติเหตุทางถนนช่วงเทศกาลสงกรานต์ 2565': 'name',
#  'น่าน เปิดศูนย์ป้องกันอุบัติเหตุช่วงสงกรานต์': 'name',
#  'กระบี่-เปิดศูนย์ปฏิบัติการร่วมป้องกันและลดอุบัติเหตุทางถนนและทางทะเลช่วงเทศกาลสงกรานต์ (มีคลิป)': 'name',
#  'ลำปาง เปิดศูนย์รณรงค์ลดอุบัติเหตุทางถนนเฝ้าระวังโควิด-19ช่วงสงกรานต์': 'name',
#  'ชัยภูมิเร่งเปิดหอผู้ป่วยช่วงสงกรานต์รองรับแยกผู้ป่วยเพิ่มทั้งอุบัติเหตุ-โควิดยังพุ่ง!': 'name',
#  'สกัดจยย.แต่งซิ่ง ป้องกันอุบัติเหตุ 7 วัน อันตราย': 'name',
#  'ตำรวจช่าง สภ.สระบัว ช่วยซ่อมแซมถนนพัง เพื่อลดอุบัติเหตุช่วงเทศกาลสงกรานต์': 'name',
#  'ซ้อมแผนอุบัติเหตุหมู่รับเทศกาลสงกรานต์ จ.สระแก้ว': 'name',
#  'ระนองเปิดศูนย์ปฏิบัติการร่วมป้องกันและลดอุบัติเหตุทางถนนช่วงเทศกาลสงกรานต์': 'name',
#  'ตร.มหาชัย ตั้งด่านแจกหมวกกันน็อก รณรงค์ลดอุบัติเหตุสงกรานต์': 'name',
#  'สภ เมืองพัทยา เตรียมความพร้อมป้องกันอุบัติเหตุบนถนน': 'name',
#  'AIS มอบประกันอุบัติเหตุฟรี ต้อนรับสงกรานต์ 65': 'name',
#  'นครนายก-อุบัติเหตุ รถกระบะชนกับรถกระบะ คู่กรณีหลบหนี (มีคลิป)': 'name',
#  'พังงา-ไฮโซปลาวาฬ\u200b ซิ่งเก๋งหรูเบนท์ลี่ย์ราคา\u200bกว่า 30 ล้าน เกิดอุบัติเหตุ\u200bไฟไหม้วอดทั้งคัน\u200b\xa0\xa0\xa0\xa0': 'name',
#  '“คลองขลุง” จัดกิจกรรมรณรงค์ปลอดภัยทางข้าม ไร้อุบัติเหตุจุดจราจรหนาแน่น': 'name',
#  'คืนสลด อุบัติเหตุสองราย ตาย 3 ศพ': 'name',
#  'ระนอง รับนโยบาย เสริมสร้างประสิทธิภาพการป้องกันและลดอุบัติเหตุทางถนน': 'name',
#  'เครื่องบินเอฟ 16 ทอ. ประสบอุบัติเหตุระหว่างฝึกบิน นักบินปลอดภัย': 'name',
#  'เจ้าของคลิป เผยน้องใส่หน้ากากผีเป็นออทิสติกชอบแกล้งคนไม่มีอะไร แต่ก็เป็นห่วงกลัวเกิดอุบัติเหตุ': 'name',
#  'นายกเทศมนตรีนครรังสิตปรับปรุงทางม้าลายลดอุบัติเหตุหน้าโรงเรียน': 'name',
#  'ชื่นชม ครอบครัวหนุ่มประสบอุบัติเหตุ บริจาคหัวใจต่อลมหายใจผู้ป่วย': 'name',
#  'ปทุมธานี รณรงค์ลดอุบัติเหตุบริเวณทางข้าม ปรับปรุงทาสีใหม่ให้มีความเด่นชัด สร้างความปลอดภัยทางถนน': 'name',
#  'สมุทรสาคร รณรงค์ผู้ขับขี่หยุดให้คนข้ามทางม้าลาย ลดอุบัติเหตุ': 'name',
#  'กาฬสินธุ์รณรงค์ลดอุบัติเหตุบริเวณทางข้าม': 'name',
#  'ระนองเปิดกิจกรรม “พาน้องข้ามถนน” เริ่มสัปดาห์รณรงค์เพื่อลดอุบัติเหตุทางข้าม': 'name',
#  'ลำปาง Kick off รณรงค์ลดอุบัติเหตุบริเวณทางข้าม สร้างจิตสำนึกการใช้รถใช้ถนน': 'name',
#  'แม่-ลูก จยย.ล้มทับแม่ช่วยเหลือตัวเองไม่ได้ ช่วงเวลาเร่งด่วนหวั่นอุบัติเหตุซ้ำ ชาวบ้านประสานกู้ภัยช่วย': 'name',
#  'อุบัติเหตุหนุ่มใหญ่พ่อค้าขายของประจำโรงงาน รถเสียหลักหลุดโค้งหวิดสิ้นชื่อ': 'name',
#  'อุบัติเหตุรถเก๋งเบรกไม่ทัน ชนท้ายรถบรรทุกไข่พลิกคว่ำไข่กระจายเสียหายทั้งคัน': 'name',
#  'อุบัติเหตุรถเฉี่ยวชนนักเรียนได้รับบาดเจ็บ จ.ปราจีนบุรี': 'name',
#  'ทม.หัวหิน ทาสีทางม้าลายแบบใหม่สีขาว-แดง เห็นเด่นชัด ป้องกันอุบัติเหตุ': 'name',
#  'ประมูลทะเบียนเลขสวย จ.สระแก้ว นํารายได้ช่วยเหลือผู้พิการจากอุบัติเหตุและการใช้รถใช้ถนนไม่คึกคัก': 'name',
#  'สาวร้องเสียงหลงรถพ่วงบรรทุกไม้ซิ่งแหวกเลนขวาไม้ตกใส่รถหวิดเกิดอุบัติเหตุ': 'name',
#  'ปทุมธานี ซ้อมใหญ่แผนป้องกันอุบัติเหตุทางม้าลาย สมจริงจนประชาชนตกใจต้องหยุดรถดู': 'name',
#  'อุบัติเหตุรถยนต์เสียหลักตกถนนรับวันตรุษจีน จ.ปราจีนบุรี': 'name',
#  'ตำรวจภูธรภาค 3 มอบโล่ประกาศเกียรติคุณ ให้แก่ ภาคีเครือข่ายและหน่วยงานในสังกัดที่มีผลการปฏิบัติงานดีเด่น ด้านการ ป้องกันและลดอุบัติเหตุทางถนน ในห้วงเทศกาลปีใหม่ พ.ศ.2565': 'name',
#  'ลำปางเร่งปรับปรุงทาสีเส้นทางม้าลายจุดเสี่ยง หวังลดอุบัติเหตุทางถนน': 'name',
#  'คุณยายวัย 67 ปีเช้าบวชลูกชาย บ่ายหลานชายประสบอุบัติเหตุเสียชีวิต เช้าวันรุ่งขึ้นคุณยายตรอมใจดับตาม': 'name',
#  'ถึงฤดูกาลลื่นไถล อุบัติเหตุระดมคว่ำยามเช้าต่อเนื่องบนทางสายเดิมที่แก้ไม่ตก': 'name',
#  'ดวงถึงฆาต!! “นายกคิงส์” ทรงยศ เทียนทอง อดีตนายก อบจ.สระแก้ว ถูกรถชนเสียชีวิตหลังรถเกิดอุบัติเหตุ': 'name',
#  'อุบัติเหตุรถพ่วง 18 ล้อ ซิ่งฝ่าไฟแดงชน 10 ล้อ สนั่นแยกสระขวัญหลายคัน': 'name',
#  'เพชรบูรณ์-เกิดอุบัติเหตุซ้อน รถพยาบาลฉุกเฉิน ชนรถสายตรวจตร. กลางแยกยูเทิร์น เจ็บระนาว 7 ราย (ชมคลิป)': 'name',
#  'ชายอายุราว 50 ปี เกิดอุบัติเหตุรถกระบะตกในร่องถนน ติดอยู่ในรถออกไม่ได้': 'name',
#  '(ชมคลิป) ยูเทิร์นวัดใจ เจ็บตายบ่อย เกิดอุบัติเหตุอีกแล้ว\xa0': 'name',
#  'พลิกตะแคงหวิดดับ อุบัติเหตุรถยนต์ชนสนั่น 3 คัน พังยับ': 'name',
#  'เกิดอุบัติเหตุรถบรรทุกสารเคมีพลิกคว่ำที่ จ.ปราจีนบุรี': 'name'}

# %%
G = nx.Graph(graph_data)
G

# %%
node_colors = {elm:'skyblue' if elm in news_titles else 'yellow' for elm in G.nodes()}
node_colors
# Out:
# {'สงขลา ปาดังเบซาร์-ท่าข่อย ถนนพังเป็นหลุมใหญ่ เกิดอุบัติเหตุหลายครั้ง หน่วยงานฯเมิน': 'skyblue',
#  '07 พ.ย. 2022': 'yellow',
#  'เพชรบูรณ์-ผญบ.ทับเบิกเบื่อทนฟัง 9 ปีอยู่ในเขตป่า นำชาวบ้านเดินหน้าลุยซ่อมถนน โดยไม่ใช้งบฯราชการ หลังนทท.เกิดอุบัติเหตุบ่อย': 'skyblue',
#  '02 พ.ย. 2022': 'yellow',
#  'อุบัติเหตุสยอง!! ปิคอัพชน จยย.พ่วงข้างอย่างจัง ร่างปลิวตกสะพานข้ามคลองพระสทึงจมดับ': 'skyblue',
#  '29 ต.ค. 2022': 'yellow',
#  'ลำปางรณรงค์ลดอุบัติเหตุทางข้ามเคร่งครัดบังคับใช้กฎหมาย พ.ร.บ.จราจรทางบก': 'skyblue',
#  '26 ต.ค. 2022': 'yellow',
#  'นครนายก- (มีคลิป) อุบัติเหตุรถยนต์เสียหลักพุ่งชนเสาไฟฟ้า ดับ 1 สาหัส 4 ราย เจ็บเล็กน้อย 1 ราย': 'skyblue',
#  '09 ต.ค. 2022': 'yellow',
#  'ชาวบ้านวอนซ่อมถนนพัง ถนนสาย 304 หวิดเกิดอุบัติเหตุทุกวินาที': 'skyblue',
#  '06 ต.ค. 2022': 'yellow',
#  'สงขลา ซ้ำซาก!!! อุบัติเหตุรถยนต์กระบะชนท้ายเทรลเลอร์ “อส.สะเดา”ดับพร้อมภรรยา': 'skyblue',
#  '24 ก.ย. 2022': 'yellow',
#  'เมืองกาญจน์ Kick off สวมหมวกนิรภัย 100% รณรงค์สร้างจิตสำนึกลดอุบัติเหตุบนท้องถนน (ชมคลิป)': 'skyblue',
#  '21 ก.ย. 2022': 'yellow',
#  'ตรังจัดป้องกันการเกิดอุบัติเหตุและรณรงค์สวมหมวกนิรภัย 100 เปอร์เซ็นต์': 'skyblue',
#  'ชาวบ้านสุดจะทน!! ขนต้นไม้ปลูกกลางถนนสายหลัก หลังถนนพังเกิดอุบัติเหตุบ่อย จ.สระแก้ว': 'skyblue',
#  'นครนายก-อุบัติเหตุรถเก๋งพุ่งชน รถจยย. คนขี่รถจยย. ลอยไปกระแทกเสาฟ้า ดับคาที่': 'skyblue',
#  '14 ก.ย. 2022': 'yellow',
#  'อุบัติเหตุซ้ำซาก!! รถพ่วง 22 ล้อ บรรทุกไม้ไผ่พลิกคว่ำปิดทางขึ้น-ลง ช่องเขาตะโกเป็นอัมพาตเกือบครึ่งวัน': 'skyblue',
#  '10 ก.ย. 2022': 'yellow',
#  'สระแก้ว ฝนตกหนักถนนลื่นเกิดอุบัติเหตุกระบะเสียหลักพลิกคว่ำชนเสาไฟฟ้าดับ 1 ราย': 'skyblue',
#  '08 ก.ย. 2022': 'yellow',
#  'รณรงค์เพื่อลดอุบัติเหตุบริเวณทางข้าม': 'skyblue',
#  '21 ส.ค. 2022': 'yellow',
#  'รพ.ลำปาง เปิดศูนย์อุบัติเหตุฉุกเฉินอัจฉริยะและหอผู้ป่วยวิกฤต เสริมประสิทธิภาพด้านการรักษา': 'skyblue',
#  '20 ส.ค. 2022': 'yellow',
#  'ผอ.สถาบันฯ ปิดทองหลังพระฯ ประสบอุบัติเหตุเสียชีวิต ที่เพชรบุรี': 'skyblue',
#  '18 ส.ค. 2022': 'yellow',
#  'ตายอีก 1 ราย อุบัติเหตุหมู่นักเรียนขับปิกอัพพลิกคว่ำชนเสาไฟฟ้า จ.สระแก้ว': 'skyblue',
#  'ลำพูน การนิคมฯนำพนักงาน ผู้ประกอบการและประชาชน อบรมสร้างวินัยจราจรลดอุบัติเหตุและการเสียชีวิต': 'skyblue',
#  '15 ส.ค. 2022': 'yellow',
#  'มอบโลงศพบริจาคช่วยนักเรียนที่ประสบอุบัติเหตุหมู่ แม่เผยหัวใจแทบสลาย มีลูกแค่คนเดียว ไม่อยากให้เด็กเอารถยนต์มาใช้กันเองแบบนี้': 'skyblue',
#  '13 ส.ค. 2022': 'yellow',
#  'นายอำเภอธาตุพนม มอบสินไหมให้ทายาทผู้ประสบอุบัติเหตุ 8 ราย': 'skyblue',
#  '04 ส.ค. 2022': 'yellow',
#  'บรรทุกหนัก!! อุบัติเหตุ 10 ล้อ หัวพ่วงขาดกระเด็นข้ามเลนชนกันสนั่นพังยับ พระเจ็บ 3 ราย รถติดระนาว': 'skyblue',
#  '03 ส.ค. 2022': 'yellow',
#  'คณะกรรมการสอบสวนอุบัติเหตุและอุบัติการณ์ของอากาศยาน (กสอ.)ได้อนุญาตให้มีการเคลื่อนย้ายอากาศยาน': 'skyblue',
#  '02 ส.ค. 2022': 'yellow',
#  'นครนายก-อุบัติเหตุรถพ่วงพุ่งชนรถ 6 ล้อกับรถกระบะ 2 คันรวด': 'skyblue',
#  '01 ส.ค. 2022': 'yellow',
#  'สลดรถทัวร์ นทท.ชาวไทยเกิดอุบัติเหตุที่ลาวเสียชีวิต 5 ราย 2 รายเป็นชาวขอนแก่น': 'skyblue',
#  'อันตรายสายเคเบิ้ลเกลื่อนพื้นถนนจนทำให้เกิดอุบัติเหตุเกี่ยวรถจักรยานยนต์': 'skyblue',
#  '27 ก.ค. 2022': 'yellow',
#  'สุดสลด “กอล์ฟ กิ๊ฟช็อป”หนุ่มพิการสู้ชีวิตประสบอุบัติเหตุเสียชีวิต': 'skyblue',
#  '26 ก.ค. 2022': 'yellow',
#  'เตือนภัย จุดตัดถนนทางรถไฟ สุดอันตราย อุบัติเหตุซ้ำซาก วอนหน่วยงานรับผิดชอบแก้ไขด่วน': 'skyblue',
#  'หนุ่มโวย !!! แท่งแบริเออร์ไม่มีอะไรใส่ถ่วงน้ำหนักรถเยียบปลิวว่อน ทำรถ จยย.วิ่งทับเกิดอุบัติเหตุ': 'skyblue',
#  '22 ก.ค. 2022': 'yellow',
#  'ฝนตกในพื้นที่ภูเก็ต จักรยานยนต์เกิดอุบัติเหตุหลายราย นายกราไวย์เตือนขับขี่ระมัดระวัง': 'skyblue',
#  '21 ก.ค. 2022': 'yellow',
#  'ชาวบ้านโวยกรมทางหลวงสร้างทาง 4 ช่องจราจร มีการปลูกหญ้าข้างแท่งคอนกรีตเกาะกลางถนนทำให้เสี่ยงเกิดอุบัติเหตุ\xa0': 'skyblue',
#  '20 ก.ค. 2022': 'yellow',
#  'พัทลุง-อุบัติเหตุซ้ำเฮลิคอปเตอร์แบล็กฮอว์กคณะของแม่ทัพภาค 4 ขณะขนย้าย ไปที่ จ.ลพบุรี เพื่อพิสูจน์หาสาเหตุ': 'skyblue',
#  '18 ก.ค. 2022': 'yellow',
#  'ปราจีนบุรี อุบัติเหตุกระบะเสียหลักชนคอสะพานหวิดดับยกครัว': 'skyblue',
#  'สงขลา ด่วน !!! อุบัติเหตุ ฮ.เเม่ทัพภาค 4 ตกกลางสวนยาง โชคดีแค่บาดเจ็บ': 'skyblue',
#  '15 ก.ค. 2022': 'yellow',
#  'ขอนแก่นตั้งศูนย์ปฏิบัติการป้องกันและลดอุบัติเหตุทางถนนช่วงเทศกาลหยุดยาว 13 -17 ก.ค. 2565': 'skyblue',
#  '12 ก.ค. 2022': 'yellow',
#  'อุบัติเหตุสลดคร่าชีวิต สจ.คนดัง 2 สมัย': 'skyblue',
#  '06 ก.ค. 2022': 'yellow',
#  'ผู้รับเหมา ปรับปรุงผิวจราจร กลางคืนไร้แสงไฟ เกิดอุบัติเหตุบ่อยครั้งจนทำให้ปู่วัย 81 ปีเสียชีวิต': 'skyblue',
#  '16 มิ.ย. 2022': 'yellow',
#  'ยิงกันในงานบวชที่เพชรบุรี คนยิงหนีไปเกิดอุบัติเหตุจนปืนตก แต่ก็ยังขับรถหนีไปได้': 'skyblue',
#  '12 มิ.ย. 2022': 'yellow',
#  'อุบัติเหตุสลดรับอุรณ รถตู้โดยสารชนชายนุ่งขาวเสียชีวิตคาที่': 'skyblue',
#  '11 มิ.ย. 2022': 'yellow',
#  'เกิดอุบัติเหตุยางรถไถระเบิดใส่หน้าเสียชีวิตคาที่ จ.สระแก้ว': 'skyblue',
#  '04 มิ.ย. 2022': 'yellow',
#  '“นครพนมมีแต่คนน่ารัก” ผจก.ร้านเหล้าเผย ลูกค้าเมากลัวอุบัติเหตุเปิดพัดลมให้นอน': 'skyblue',
#  '31 พ.ค. 2022': 'yellow',
#  '(คลิป) มือดีโทรแจ้งตร.ตรัง มีอุบัติเหตุใหญ่ จนท.-นักข่าว บึ่งรถไม่แคร์น้ำมันแพง แต่พบแค่ความว่างเปล่า': 'skyblue',
#  '30 พ.ค. 2022': 'yellow',
#  'ปทุมธานี เดินหน้ารณรงค์ “ลดอุบัติเหตุบริเวณทางข้ามและสวมหมวกนิรภัย 100 %” มุ่งสร้างวินัยจราจร': 'skyblue',
#  '23 พ.ค. 2022': 'yellow',
#  'นายอำเภอเมืองลพบุรีห่วงใยประชาชนนำรณรงค์การลดอุบัติเหตุทางถนน': 'skyblue',
#  '20 พ.ค. 2022': 'yellow',
#  'สงขลา รถตำรวจ สภ.ตะโหมด ประสบอุบัติเหตุชนราวสะพาน โชคดีแค่บาดเจ็บ': 'skyblue',
#  '16 พ.ค. 2022': 'yellow',
#  'ตำรวจนครนายกตรวจเข้มหยุดยาว 4 วัน หวั่นเกิดอุบัติเหตุ และอาชญากรรม': 'skyblue',
#  '14 พ.ค. 2022': 'yellow',
#  'อุบัติเหตุสลด!! กระบะยางแตกพลิกคว่ำ เด็กหญิง 1 ขวบครึ่งดับ': 'skyblue',
#  '08 พ.ค. 2022': 'yellow',
#  'พุ่งชนจังจัง!! กล้องหน้ารถจับภาพชัด อุบัติเหตุลุงขับรถ จยย.หลุดโค้ง เสยรถเก๋งดับคาที่': 'skyblue',
#  '07 พ.ค. 2022': 'yellow',
#  'โคราช!!! ยึดยาบ้า 8 ล้านเม็ด หลังได้รับแจ้งว่ามีอุบัติเหตุ': 'skyblue',
#  '02 พ.ค. 2022': 'yellow',
#  'ญาติร่ำไห้ลั่น!! ถนนสุดอันตราย ร้องเรียนอุบัติเหตุซ้ำซาก ขูดถนนทำใหม่ จยย.เสียหลักถูกพ่วง 22 ล้อ ทับหัวตายคาที่': 'skyblue',
#  '29 เม.ย. 2022': 'yellow',
#  'อุบัติเหตุ รถบรรทุกตู้คอนเทนเนอร์ เสียหลัก ทำตู้ฯหล่นบนถนน โชคดีไร้ผู้บาดเจ็บ': 'skyblue',
#  '23 เม.ย. 2022': 'yellow',
#  'ผู้สมัครนายกเมืองพัทยา หมายเลข 2 ช่วยเหลือประชาชนประสบอุบัติเหตุ': 'skyblue',
#  '18 เม.ย. 2022': 'yellow',
#  'ฝนตกหนักเกิดอุบัติเหตุรถกระบะชนรถกระบะ เสียชีวิตคาที่ 1 บาดเจ็บอีก 1': 'skyblue',
#  'ครอบครัวร้องขอความเป็นธรรม ลูกตาย 3 ปี คดีไม่คืบ-ไม่เชื่อเป็นอุบัติเหตุ': 'skyblue',
#  'กระบี่-วันที่ 6 ช่วงสงกรานต์ มีอุบัติเหตุสะสม 28 ครั้งเสียชีวิต 2 ราย': 'skyblue',
#  '17 เม.ย. 2022': 'yellow',
#  'อุบัติเหตุสระแก้ว 6 วันตาย 7 ศพ แห่เดินทางกลับวันสุดท้าย': 'skyblue',
#  'กระบี่-วันที่สี่ช่วงสงกรานต์ มีอุบัติเหตุสะสมตายแล้ว 2 ราย': 'skyblue',
#  '15 เม.ย. 2022': 'yellow',
#  'นครฯ – 3 วันสงกรานต์เมืองคอน เกิดอุบัติเหตุ 33 ครั้ง (สูงสุดของประเทศ) ตาย 1 เจ็บ 36 คน': 'skyblue',
#  '14 เม.ย. 2022': 'yellow',
#  'อุบัติเหตุเซ่นสงกรานต์ 7 วันอันตราย เสียชีวิต 2 ศพ จ.สระแก้ว': 'skyblue',
#  'กระบี่-วันที่สามช่วงสงกรานต์ มีอุบัติเหตุสะสมแล้ว 10 ครั้ง': 'skyblue',
#  'กระบี่-วันที่สองช่วงสงกรานต์ มีอุบัติเหตุสะสมแล้ว 5 ครั้ง': 'skyblue',
#  '13 เม.ย. 2022': 'yellow',
#  'พัทลุง-ศูนย์อุบัติเหตุในช่วง 7 วันอันตราย เทศกาลสงกรานต์ สรุปผลวันแรก 2 ศพ -77ข่าวเด็ด': 'skyblue',
#  '12 เม.ย. 2022': 'yellow',
#  'เพชรบูรณ์-อุบัติเหตุดับรายแรก เซ่น 7 วันอันตรายช่วงสงกรานต์': 'skyblue',
#  'กระบี่-7 วันแรกช่วงสงกรานต์ มีอุบัติเหตุแล้ว 2 ครั้ง': 'skyblue',
#  'ชาวบ้านร้องขอสัณญานไฟจราจร หวังลดอุบัติเหตุและไม่ต้องไปกลับรถไกล': 'skyblue',
#  '11 เม.ย. 2022': 'yellow',
#  'ผู้ว่าพังงาปล่อยขบวนรณรงค์ 7 วันอันตรายคุมเข้มลดอุบัติเหตุทางถนนช่วงเทศกาลสงกรานต์ 2565': 'skyblue',
#  'น่าน เปิดศูนย์ป้องกันอุบัติเหตุช่วงสงกรานต์': 'skyblue',
#  'กระบี่-เปิดศูนย์ปฏิบัติการร่วมป้องกันและลดอุบัติเหตุทางถนนและทางทะเลช่วงเทศกาลสงกรานต์ (มีคลิป)': 'skyblue',
#  'ลำปาง เปิดศูนย์รณรงค์ลดอุบัติเหตุทางถนนเฝ้าระวังโควิด-19ช่วงสงกรานต์': 'skyblue',
#  'ชัยภูมิเร่งเปิดหอผู้ป่วยช่วงสงกรานต์รองรับแยกผู้ป่วยเพิ่มทั้งอุบัติเหตุ-โควิดยังพุ่ง!': 'skyblue',
#  'สกัดจยย.แต่งซิ่ง ป้องกันอุบัติเหตุ 7 วัน อันตราย': 'skyblue',
#  'ตำรวจช่าง สภ.สระบัว ช่วยซ่อมแซมถนนพัง เพื่อลดอุบัติเหตุช่วงเทศกาลสงกรานต์': 'skyblue',
#  '08 เม.ย. 2022': 'yellow',
#  'ซ้อมแผนอุบัติเหตุหมู่รับเทศกาลสงกรานต์ จ.สระแก้ว': 'skyblue',
#  '07 เม.ย. 2022': 'yellow',
#  'ระนองเปิดศูนย์ปฏิบัติการร่วมป้องกันและลดอุบัติเหตุทางถนนช่วงเทศกาลสงกรานต์': 'skyblue',
#  'ตร.มหาชัย ตั้งด่านแจกหมวกกันน็อก รณรงค์ลดอุบัติเหตุสงกรานต์': 'skyblue',
#  'สภ เมืองพัทยา เตรียมความพร้อมป้องกันอุบัติเหตุบนถนน': 'skyblue',
#  'AIS มอบประกันอุบัติเหตุฟรี ต้อนรับสงกรานต์ 65': 'skyblue',
#  'นครนายก-อุบัติเหตุ รถกระบะชนกับรถกระบะ คู่กรณีหลบหนี (มีคลิป)': 'skyblue',
#  '26 มี.ค. 2022': 'yellow',
#  'พังงา-ไฮโซปลาวาฬ\u200b ซิ่งเก๋งหรูเบนท์ลี่ย์ราคา\u200bกว่า 30 ล้าน เกิดอุบัติเหตุ\u200bไฟไหม้วอดทั้งคัน\u200b\xa0\xa0\xa0\xa0': 'skyblue',
#  '25 มี.ค. 2022': 'yellow',
#  '“คลองขลุง” จัดกิจกรรมรณรงค์ปลอดภัยทางข้าม ไร้อุบัติเหตุจุดจราจรหนาแน่น': 'skyblue',
#  '23 มี.ค. 2022': 'yellow',
#  'คืนสลด อุบัติเหตุสองราย ตาย 3 ศพ': 'skyblue',
#  '20 มี.ค. 2022': 'yellow',
#  'ระนอง รับนโยบาย เสริมสร้างประสิทธิภาพการป้องกันและลดอุบัติเหตุทางถนน': 'skyblue',
#  '16 มี.ค. 2022': 'yellow',
#  'เครื่องบินเอฟ 16 ทอ. ประสบอุบัติเหตุระหว่างฝึกบิน นักบินปลอดภัย': 'skyblue',
#  '08 มี.ค. 2022': 'yellow',
#  'เจ้าของคลิป เผยน้องใส่หน้ากากผีเป็นออทิสติกชอบแกล้งคนไม่มีอะไร แต่ก็เป็นห่วงกลัวเกิดอุบัติเหตุ': 'skyblue',
#  '07 มี.ค. 2022': 'yellow',
#  'นายกเทศมนตรีนครรังสิตปรับปรุงทางม้าลายลดอุบัติเหตุหน้าโรงเรียน': 'skyblue',
#  '27 ก.พ. 2022': 'yellow',
#  'ชื่นชม ครอบครัวหนุ่มประสบอุบัติเหตุ บริจาคหัวใจต่อลมหายใจผู้ป่วย': 'skyblue',
#  '25 ก.พ. 2022': 'yellow',
#  'ปทุมธานี รณรงค์ลดอุบัติเหตุบริเวณทางข้าม ปรับปรุงทาสีใหม่ให้มีความเด่นชัด สร้างความปลอดภัยทางถนน': 'skyblue',
#  '23 ก.พ. 2022': 'yellow',
#  'สมุทรสาคร รณรงค์ผู้ขับขี่หยุดให้คนข้ามทางม้าลาย ลดอุบัติเหตุ': 'skyblue',
#  '22 ก.พ. 2022': 'yellow',
#  'กาฬสินธุ์รณรงค์ลดอุบัติเหตุบริเวณทางข้าม': 'skyblue',
#  'ระนองเปิดกิจกรรม “พาน้องข้ามถนน” เริ่มสัปดาห์รณรงค์เพื่อลดอุบัติเหตุทางข้าม': 'skyblue',
#  '21 ก.พ. 2022': 'yellow',
#  'ลำปาง Kick off รณรงค์ลดอุบัติเหตุบริเวณทางข้าม สร้างจิตสำนึกการใช้รถใช้ถนน': 'skyblue',
#  'แม่-ลูก จยย.ล้มทับแม่ช่วยเหลือตัวเองไม่ได้ ช่วงเวลาเร่งด่วนหวั่นอุบัติเหตุซ้ำ ชาวบ้านประสานกู้ภัยช่วย': 'skyblue',
#  '19 ก.พ. 2022': 'yellow',
#  'อุบัติเหตุหนุ่มใหญ่พ่อค้าขายของประจำโรงงาน รถเสียหลักหลุดโค้งหวิดสิ้นชื่อ': 'skyblue',
#  '13 ก.พ. 2022': 'yellow',
#  'อุบัติเหตุรถเก๋งเบรกไม่ทัน ชนท้ายรถบรรทุกไข่พลิกคว่ำไข่กระจายเสียหายทั้งคัน': 'skyblue',
#  '11 ก.พ. 2022': 'yellow',
#  'อุบัติเหตุรถเฉี่ยวชนนักเรียนได้รับบาดเจ็บ จ.ปราจีนบุรี': 'skyblue',
#  '09 ก.พ. 2022': 'yellow',
#  'ทม.หัวหิน ทาสีทางม้าลายแบบใหม่สีขาว-แดง เห็นเด่นชัด ป้องกันอุบัติเหตุ': 'skyblue',
#  '08 ก.พ. 2022': 'yellow',
#  'ประมูลทะเบียนเลขสวย จ.สระแก้ว นํารายได้ช่วยเหลือผู้พิการจากอุบัติเหตุและการใช้รถใช้ถนนไม่คึกคัก': 'skyblue',
#  '05 ก.พ. 2022': 'yellow',
#  'สาวร้องเสียงหลงรถพ่วงบรรทุกไม้ซิ่งแหวกเลนขวาไม้ตกใส่รถหวิดเกิดอุบัติเหตุ': 'skyblue',
#  '04 ก.พ. 2022': 'yellow',
#  'ปทุมธานี ซ้อมใหญ่แผนป้องกันอุบัติเหตุทางม้าลาย สมจริงจนประชาชนตกใจต้องหยุดรถดู': 'skyblue',
#  '01 ก.พ. 2022': 'yellow',
#  'อุบัติเหตุรถยนต์เสียหลักตกถนนรับวันตรุษจีน จ.ปราจีนบุรี': 'skyblue',
#  'ตำรวจภูธรภาค 3 มอบโล่ประกาศเกียรติคุณ ให้แก่ ภาคีเครือข่ายและหน่วยงานในสังกัดที่มีผลการปฏิบัติงานดีเด่น ด้านการ ป้องกันและลดอุบัติเหตุทางถนน ในห้วงเทศกาลปีใหม่ พ.ศ.2565': 'skyblue',
#  '26 ม.ค. 2022': 'yellow',
#  'ลำปางเร่งปรับปรุงทาสีเส้นทางม้าลายจุดเสี่ยง หวังลดอุบัติเหตุทางถนน': 'skyblue',
#  '25 ม.ค. 2022': 'yellow',
#  'คุณยายวัย 67 ปีเช้าบวชลูกชาย บ่ายหลานชายประสบอุบัติเหตุเสียชีวิต เช้าวันรุ่งขึ้นคุณยายตรอมใจดับตาม': 'skyblue',
#  '21 ม.ค. 2022': 'yellow',
#  'ถึงฤดูกาลลื่นไถล อุบัติเหตุระดมคว่ำยามเช้าต่อเนื่องบนทางสายเดิมที่แก้ไม่ตก': 'skyblue',
#  'ดวงถึงฆาต!! “นายกคิงส์” ทรงยศ เทียนทอง อดีตนายก อบจ.สระแก้ว ถูกรถชนเสียชีวิตหลังรถเกิดอุบัติเหตุ': 'skyblue',
#  '20 ม.ค. 2022': 'yellow',
#  'อุบัติเหตุรถพ่วง 18 ล้อ ซิ่งฝ่าไฟแดงชน 10 ล้อ สนั่นแยกสระขวัญหลายคัน': 'skyblue',
#  '16 ม.ค. 2022': 'yellow',
#  'เพชรบูรณ์-เกิดอุบัติเหตุซ้อน รถพยาบาลฉุกเฉิน ชนรถสายตรวจตร. กลางแยกยูเทิร์น เจ็บระนาว 7 ราย (ชมคลิป)': 'skyblue',
#  '14 ม.ค. 2022': 'yellow',
#  'ชายอายุราว 50 ปี เกิดอุบัติเหตุรถกระบะตกในร่องถนน ติดอยู่ในรถออกไม่ได้': 'skyblue',
#  '(ชมคลิป) ยูเทิร์นวัดใจ เจ็บตายบ่อย เกิดอุบัติเหตุอีกแล้ว\xa0': 'skyblue',
#  '10 ม.ค. 2022': 'yellow',
#  'พลิกตะแคงหวิดดับ อุบัติเหตุรถยนต์ชนสนั่น 3 คัน พังยับ': 'skyblue',
#  '09 ม.ค. 2022': 'yellow',
#  'เกิดอุบัติเหตุรถบรรทุกสารเคมีพลิกคว่ำที่ จ.ปราจีนบุรี': 'skyblue',
#  '07 ม.ค. 2022': 'yellow'}

# %% [markdown]
# # visualize raw data

# %%
title = "News and NameEntities"
HOVER_TOOLTIPS = [("Character", "@index")]
nx.set_node_attributes(G, node_colors, 'node_colors')
plot = figure(tooltips = HOVER_TOOLTIPS,
              tools="pan,wheel_zoom,save,reset,hover", active_scroll='wheel_zoom',
            x_range=Range1d(-10.1, 10.1), y_range=Range1d(-10.1, 10.1), title=title,
              frame_width=1200, frame_height=800
 )

network_graph = from_networkx(G, nx.kamada_kawai_layout, scale=10, center=(0, 0))
network_graph.node_renderer.glyph = Circle(size=15, fill_color='node_colors')
network_graph.edge_renderer.glyph = MultiLine(line_alpha=0.5, line_width=1)
plot.renderers.append(network_graph)
show(plot)
# Out:
#   <div class="bk-root" id="2b8ad70f-0aa7-45ab-b312-25e7f00021d4" data-root-id="1005"></div>

# %% [markdown]
# # Compute betweenness_centrality graph

# %%
def cal_size(val, k=10, k2=1000):
    val = val * k * k2
    if val > k: 
        return val
    return k

# %%
graph_values = nx.centrality.betweenness.betweenness_centrality(G)
node_size = {k:cal_size(v, k=10, k2=1000) for k,v in graph_values.items()}

# %%
title = "betweenness_centrality"
HOVER_TOOLTIPS = [("Character", "@index")]

nx.set_node_attributes(G, node_size, 'node_size')
nx.set_node_attributes(G, node_colors, 'node_colors')

plot = figure(tooltips = HOVER_TOOLTIPS,
              tools="pan,wheel_zoom,save,reset,hover", active_scroll='wheel_zoom',
            x_range=Range1d(-10.1, 10.1), y_range=Range1d(-10.1, 10.1), title=title,
              frame_width=1200, frame_height=800
)

network_graph = from_networkx(G, nx.kamada_kawai_layout, scale=10, center=(0, 0))
network_graph.node_renderer.glyph = Circle(fill_color='node_colors', size='node_size')
network_graph.edge_renderer.glyph = MultiLine(line_alpha=0.5, line_width=1)
plot.renderers.append(network_graph)
show(plot)
# Out:
#   <div class="bk-root" id="34eba73b-a01a-4fcc-ac5f-a35ed9f7b8dc" data-root-id="1193"></div>

# %% [markdown]
# # compute eigenvector_centrality

# %%
graph_values = nx.centrality.eigenvector.eigenvector_centrality(G, max_iter=600)
node_size = {k:cal_size(v, k=10, k2=15) for k,v in graph_values.items()}

# %%
title = "xxx"
HOVER_TOOLTIPS = [("Character", "@index")]

nx.set_node_attributes(G, node_size, 'node_size') 
nx.set_node_attributes(G, node_colors, 'node_colors')

plot = figure(tooltips = HOVER_TOOLTIPS,
              tools="pan,wheel_zoom,save,reset,hover", active_scroll='wheel_zoom',
            x_range=Range1d(-10.1, 10.1), y_range=Range1d(-10.1, 10.1), title=title,
              frame_width=1200, frame_height=800
)

network_graph = from_networkx(G, nx.kamada_kawai_layout, scale=10, center=(0, 0))
network_graph.node_renderer.glyph = Circle(fill_color='node_colors', size='node_size')
network_graph.edge_renderer.glyph = MultiLine(line_alpha=0.5, line_width=1)
plot.renderers.append(network_graph)
show(plot)
# Out:
#   <div class="bk-root" id="180040df-6f47-4422-b0b7-815b52ff727c" data-root-id="1402"></div>
