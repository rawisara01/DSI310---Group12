# %%
# !pip install beautifulsoup4
# !pip install requests
# !pip install openpyxl
# Out:
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4) (2.3.2.post1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (2.28.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/conda/lib/python3.10/site-packages (from requests) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests) (2022.6.15)
# Requirement already satisfied: openpyxl in /opt/conda/lib/python3.10/site-packages (3.0.10)
# Requirement already satisfied: et-xmlfile in /opt/conda/lib/python3.10/site-packages (from openpyxl) (1.1.0)

# %%
import pandas as pd
import bs4
import requests
from bs4 import BeautifulSoup
import csv

# %%
title_list = []
date_list = []
detail_list = []

# %%
page = 1
while page <= 5:
  data = requests.get('https://thestandard.co/page/'+str(page)+'?s=%E0%B8%AD%E0%B8%B8%E0%B8%9A%E0%B8%B1%E0%B8%95%E0%B8%B4%E0%B9%80%E0%B8%AB%E0%B8%95%E0%B8%B8&search=')
  soup = bs4.BeautifulSoup(data.text,"html.parser")
  for f in soup.find_all('div', class_='col-md-8'):
    title_list.append(f.find('h3', class_= 'news-title').find('a').text.strip())
    date_list.append(f.find('div', class_='date').text.strip())
    detail_list.append(f.find('div', class_='desc').text.strip())
  page += 1

# %%
table = pd.DataFrame([title_list,date_list,detail_list]).transpose()

# %%
table.columns = ['TITLE', 'date', 'DETAIL']

# %%
table.set_index('TITLE')
# Out:
#                                                                   date  \
# TITLE
# Leslie Jordan เสียชีวิตจากอุบัติเหตุทางรถยนต์ด้...      25 ตุลาคม 2022
# ยูเครนเผย หลายเมืองที่ยึดคืนได้เสียหายหนัก ขณะท...     15 กันยายน 2022
# เปาตี๋-ฑีธิชัย นวลจันทร์ อดีตผู้ตัดสินฟีฟ่าเสีย...      3 กันยายน 2022
# กทม. เพิ่มไฟกะพริบ-นกหวีด ติดตัวพนักงานกวาดถนน ...     25 สิงหาคม 2022
# ชัชชาติ ตั้งกรรมการสอบ กรณีอุบัติเหตุบันไดเลื่อ...     22 สิงหาคม 2022
# ชัชชาติมอบหมาย รองผู้ว่าฯ วิศณุ สอบอุบัติเหตุคน...     21 สิงหาคม 2022
# ตุรกีเกิดอุบัติเหตุบนท้องถนนหลายจุด รถบัส-รถบรร...     21 สิงหาคม 2022
# ‘ชัชชาติ’ ลงพื้นที่ตรวจสอบอุบัติเหตุ บันได BTS ...     21 สิงหาคม 2022
# ตร. เผย อุบัติเหตุ BTS สุรศักดิ์ เหตุเกิดจากเบี...     21 สิงหาคม 2022
# อนุทินบอก อยู่ในบัญชีนายกฯ มา 4 ปีแล้ว หากมีอุบ...     17 สิงหาคม 2022
# ครอบครัวยืนยัน ปานเพชร ผดุงชัยมวยไทยยิม นักมวยท...     24 กรกฎาคม 2022
# สำรวจอุบัติเหตุทางอากาศของกองทัพ-ตำรวจ ย้อนหลัง...     20 กรกฎาคม 2022
# เกิดอุบัติเหตุป้ายล้มทับแฟนบอล ก่อนการแข่งขันฟุ...     12 กรกฎาคม 2022
# ‘Halo’ ช่วยชีวิต โจวกวนอวี่ หลังประสบอุบัติเหตุ...      4 กรกฎาคม 2022
# อเมริกาเผยอัตราการเกิดอุบัติเหตุของรถยนต์ขับเคล...    28 มิถุนายน 2022
# เลขาฯ มูลนิธิเมาไม่ขับ ห่วงเมากัญชาแล้วขับรถ อา...    11 มิถุนายน 2022
# ดรุณวรรณ แจงเหตุ ‘สุชัชวีร์’ ข้อเท้าแพลงระหว่าง...  จากกรณีการลงพื้นที่ของ ศ.ดร.สุชัชวีร์ สุวรรณสว...
# สุชัชวีร์ขาพลิกขณะลงพื้นที่เขตคันนายาว บอกอุบัต...  วันนี้ (16 มีนาคม) ศ.ดร.สุชัชวีร์ สุวรรณสวัสดิ...
# วางดอกไม้อาลัยแตงโม ผบ.ตร. เผย พยานหลักฐานยังชี...  วันนี้ (6 มีนาคม) บรรยากาศที่ท่าเรือพิบูลสงครา...
# พ่อแม่หมอกระต่ายเข้าพบนายกฯ หารือแนวทางป้องกันอ...  วันนี้ (4 มีนาคม) นพ.แท้จริง ศิริพานิช เลขาธิก...
# แม่แตงโมเตรียมให้ทนายตรวจสอบ ปมผลประโยชน์จากประ...  วันนี้ (2 มีนาคม) พนิดา ศิระยุทธโยธิน แม่ของ แ...
# วิโรจน์ลงพื้นที่เกิดเหตุนั่งร้านถล่ม จี้ กทม. ก...  วันนี้ (16 กุมภาพันธ์) วิโรจน์ ลักขณาอดิศร ว่า...
# แม่หมอกระต่าย ร้อง กมธ.กฎหมาย สอบข้อเท็จจริงปมอ...  วันที่ (3 กุมภาพันธ์) วิสิทธิ์ พิทยาภรณ์ รองปร...
# สำรวจทางม้าลายสามมิติที่จุฬาฯ หลังโลกออนไลน์แชร...  เกิดกระแสในโลกออนไลน์หลังมีการแชร์ภาพ ‘ทางม้าล...
# ส่องสถานการณ์อุบัติเหตุทางถนนของ ‘คนเดินเท้า’ ใ...  เหตุการณ์ที่ ส.ต.ต. นรวิชญ์ บัวดก ผบ.หมู่ กองร...
# วิโรจน์ลงพื้นที่ครั้งแรกหลังเปิดตัวเป็นแคนดิเดต...  วันนี้ (24 มกราคม) ที่บริเวณหน้าโรงพยาบาลสถาบั...
# ย้อนดูข้อมูล ‘อุบัติเหตุทางถนน’ ตลอดปี 2564-ปัจ...  สืบเนื่องจากอุบัติเหตุรถจักรยานยนต์บิ๊กไบค์ชน ...
# Gaspard Ulliel นักแสดงชาวฝรั่งเศสเสียชีวิตในวัย...  Gaspard Ulliel (กัสปาร์ อุลลิแอล) นักแสดงชื่อด...
# วงการลูกหนังตุรกีเศร้า นักเตะดีกรีทีมชาติประสบอ...  วันนี้ (11 มกราคม) ข่าวเศร้าของวงการลูกหนังตุร...
# Tesla เตรียมเรียกคืนรถรุ่น Model 3 และ Model S ...  Tesla เตรียมเรียกคืนรถยนต์ประมาณ 475,000 คันใน...
# ปภ. รายงานอุบัติเหตุเฉพาะวันสิ้นปีรวม 555 ครั้ง...  วันนี้ (1 มกราคม) กรมป้องกันและบรรเทาสาธารณภัย...
# ประยุทธ์ฝากประชาชนรักษาวินัยจราจร สวมหมวกกันน็อ...  วันนี้ (30 ธันวาคม) ธนกร วังบุญคงชนะ โฆษกประจำ...
# SCB Protect ใจดี แจกฟรีประกันอุบัติเหตุสำหรับเด...  ปรมาศิริ มโนลม้าย รองผู้จัดการใหญ่อาวุโส ประธา...
# 41  Tesla เตรียมเรียกคืนรถรุ่น Model 3 และ Model S...       2 มกราคม 2022
# 42  ปภ. รายงานอุบัติเหตุเฉพาะวันสิ้นปีรวม 555 ครั้...       1 มกราคม 2022
# 43  ประยุทธ์ฝากประชาชนรักษาวินัยจราจร สวมหมวกกันน็...     30 ธันวาคม 2021
# 44  SCB Protect ใจดี แจกฟรีประกันอุบัติเหตุสำหรับเ...     29 ธันวาคม 2021
# 45  รัฐมอบประกันภัยอุบัติเหตุปีใหม่ เบี้ย 10 บาท ค...     25 ธันวาคม 2021
# 46  สสส. และเครือข่าย จัดเสวนา ห่วงปัญหาสุราทำอุบั...     22 ธันวาคม 2021
# 47  ไทเกอร์-ชาร์ลี วูดส์ ได้อันดับที่ 2 ศึก PNC Ch...     20 ธันวาคม 2021
# 48  ฌอน ไวนุย นักรักบี้นิวซีแลนด์วัย 25 ปีจากสโมสร...      18 ตุลาคม 2021
# 49  SCB Protect จับมือ DBANK เปิดขายประกันอุบัติเห...       4 ตุลาคม 2021
#
#                                                DETAIL
# 0   เมื่อวันจันทร์ที่ผ่านมา (24 ตุลาคม) เกิดข่าวที...
# 1   ประธานาธิบดี โวโลดิเมียร์ เซเลนสกี ของยูเครน เ...
# 2   เมื่อคืนวันที่ 2 กันยายนที่ผ่านมา มีรายงานว่า ...
# 3   วานนี้ (24 สิงหาคม) ที่เขตจตุจักร พญ.วันทนีย์ ...
# 4   วันนี้ (22 สิงหาคม) ที่ห้องประชุมและวางแผน War...
# 5   วันนี้ (21 สิงหาคม) ชัชชาติ สิทธิพันธุ์ ผู้ว่า...
# 6   วานนี้ (20 สิงหาคม) สำนักข่าวต่างประเทศรายงาน ...
# 7   วันนี้ (20 สิงหาคม) เมื่อเวลาประมาณ 21.35 น. ช...
# 8   วันนี้ (20 สิงหาคม) เมื่อเวลา 18.56 น. ร.ต.อ. ...
# 9   วันนี้ (17 สิงหาคม) อนุทิน ชาญวีรกูล รองนายกรั...
# 10  วันนี้ (23 กรกฎาคม) ครอบครัวของ ปานเพชร ผดุงชั...
# 11  เมื่อวันที่ 15 กรกฎาคม เกิดเหตุเฮลิคอปเตอร์แบล...
# 12  ความเคลื่อนไหวก่อนศึกฟุตบอลกระชับมิตรนัดประวัต...
# 13  การแข่งขันรถแข่งฟอร์มูลาวัน (F1) รอดพ้นจากวันแ...
# 14  เป็นครั้งแรกที่รัฐบาลสหรัฐอเมริกาเผยแพร่รายงาน...
# 15  วันนี้ (11 มิถุนายน) นพ.แท้จริง ศิริพานิช เลขา...
# 16  สดจากโค้งถนนรัชดา ผู้ว่าฯ 'ชัชชาติ' ลงพื้นที่ต...
# 17  วันนี้ (3 มิถุนายน) ที่บริเวณหน้าที่ทำการพรรคพ...
# 18  วันนี้ (2 มิถุนายน) ประศม สุขแสวง ในฐานะประธาน...
# 19  วันนี้ (17 พฤษภาคม) หลังจากที่มีรายงานจากกรุงฮ...
# 20  วันนี้ (8 พฤษภาคม) วันชัย สอนศิริ สมาชิกวุฒิสภ...
# 21  วันนี้ (4 พฤษภาคม)​​ วันชัย สอนศิริ สมาชิกวุฒิ...
# 22  วันนี้ (3 พฤษภาคม) ที่ทำเนียบรัฐบาล พล.อ. ประย...
# 23  วันนี้ (2 พฤษภาคม) สุชัชวีร์ สุวรรณสวัสดิ์ ผู้...
# 24  วันนี้ (26 เมษายน) ที่กองบัญชาการตำรวจภูธรภาค ...
# 25  วันนี้ (21 เมษายน) ธนกร วังบุญคงชนะ โฆษกประจำส...
# 26  วันนี้ (4 เมษายน) นิยม สองแก้ว อธิบดีกรมสวัสดิ...
# 27  วันนี้ (25 มีนาคม) นพ.วิทยา ชาติบัญชาชัย ประธา...
# 28  จากกรณีการลงพื้นที่ของ ศ.ดร.สุชัชวีร์ สุวรรณสว...
# 29  วันนี้ (16 มีนาคม) ศ.ดร.สุชัชวีร์ สุวรรณสวัสดิ...
# 30  วันนี้ (6 มีนาคม) บรรยากาศที่ท่าเรือพิบูลสงครา...
# 31  วันนี้ (4 มีนาคม) นพ.แท้จริง ศิริพานิช เลขาธิก...
# 32  วันนี้ (2 มีนาคม) พนิดา ศิระยุทธโยธิน แม่ของ แ...
# 33  วันนี้ (16 กุมภาพันธ์) วิโรจน์ ลักขณาอดิศร ว่า...
# 34  วันที่ (3 กุมภาพันธ์) วิสิทธิ์ พิทยาภรณ์ รองปร...
# 35  เกิดกระแสในโลกออนไลน์หลังมีการแชร์ภาพ ‘ทางม้าล...
# 36  เหตุการณ์ที่ ส.ต.ต. นรวิชญ์ บัวดก ผบ.หมู่ กองร...
# 37  วันนี้ (24 มกราคม) ที่บริเวณหน้าโรงพยาบาลสถาบั...
# 38  สืบเนื่องจากอุบัติเหตุรถจักรยานยนต์บิ๊กไบค์ชน ...
# 39  Gaspard Ulliel (กัสปาร์ อุลลิแอล) นักแสดงชื่อด...
# 40  วันนี้ (11 มกราคม) ข่าวเศร้าของวงการลูกหนังตุร...
# 41  Tesla เตรียมเรียกคืนรถยนต์ประมาณ 475,000 คันใน...
# 42  วันนี้ (1 มกราคม) กรมป้องกันและบรรเทาสาธารณภัย...
# 43  วันนี้ (30 ธันวาคม) ธนกร วังบุญคงชนะ โฆษกประจำ...
# 44  ปรมาศิริ มโนลม้าย รองผู้จัดการใหญ่อาวุโส ประธา...
# 45  วันนี้ (25 ธันวาคม) รัชดา ธนาดิเรก รองโฆษกประจ...
# 46  เมื่อวันที่ 20 ธันวาคมที่ผ่านมา มูลนิธิหญิงชาย...
# 47  ไทเกอร์ วูดส์ อดีตโปรกอล์ฟมือหนึ่งของโลก กลับม...
# 48  วันนี้ (18 ตุลาคม) ฌอน ไวนุย นักกีฬารักบี้ทีม ...
# 49  ปรมาศิริ มโนลม้าย รองผู้จัดการใหญ่อาวุโส ประธา...

# %%
table['date_split'] = table['date'].str.split('\s')

# %%
table['D'] = table['date_split'].str[0]
table['M'] = table['date_split'].str[1]
table['Y']  = table['date_split'].str[2]

# %%
table['M'].unique()
# Out:
# array(['ตุลาคม', 'กันยายน', 'สิงหาคม', 'กรกฎาคม', 'มิถุนายน', 'พฤษภาคม',
#        'เมษายน', 'มีนาคม', 'กุมภาพันธ์', 'มกราคม', 'ธันวาคม'],
#       dtype=object)

# %%
table['M'].replace({
    'มกราคม':'01',
    'กุมภาพันธ์':'02',
    'มีนาคม' :'03',
    'เมษายน':'04',
    'พฤษภาคม':'05',
     'มิถุนายน':'06',
     'กรกฎาคม':'07',
    'สิงหาคม':'08',
    'กันยายน':'09',
    'ตุลาคม':'10',
    'พฤศจิกายน':'11',
    'ธันวาคม': '12'
    }, inplace=True)

# %%
table['DATE'] = table['D']+'-'+table['M']+'-'+table['Y']

# %%
table['DATE'] = pd.to_datetime(table['DATE'])
# Out:
# /tmp/ipykernel_200/2651519125.py:1: UserWarning: Parsing '25-10-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   table['DATE'] = pd.to_datetime(table['DATE'])
# /tmp/ipykernel_200/2651519125.py:1: UserWarning: Parsing '15-09-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   table['DATE'] = pd.to_datetime(table['DATE'])
# /tmp/ipykernel_200/2651519125.py:1: UserWarning: Parsing '25-08-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   table['DATE'] = pd.to_datetime(table['DATE'])
# /tmp/ipykernel_200/2651519125.py:1: UserWarning: Parsing '22-08-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   table['DATE'] = pd.to_datetime(table['DATE'])
# /tmp/ipykernel_200/2651519125.py:1: UserWarning: Parsing '21-08-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   table['DATE'] = pd.to_datetime(table['DATE'])
# /tmp/ipykernel_200/2651519125.py:1: UserWarning: Parsing '17-08-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   table['DATE'] = pd.to_datetime(table['DATE'])
# /tmp/ipykernel_200/2651519125.py:1: UserWarning: Parsing '24-07-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   table['DATE'] = pd.to_datetime(table['DATE'])
# /tmp/ipykernel_200/2651519125.py:1: UserWarning: Parsing '20-07-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   table['DATE'] = pd.to_datetime(table['DATE'])
# /tmp/ipykernel_200/2651519125.py:1: UserWarning: Parsing '28-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   table['DATE'] = pd.to_datetime(table['DATE'])
# /tmp/ipykernel_200/2651519125.py:1: UserWarning: Parsing '17-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   table['DATE'] = pd.to_datetime(table['DATE'])
# /tmp/ipykernel_200/2651519125.py:1: UserWarning: Parsing '26-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   table['DATE'] = pd.to_datetime(table['DATE'])
# /tmp/ipykernel_200/2651519125.py:1: UserWarning: Parsing '21-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   table['DATE'] = pd.to_datetime(table['DATE'])
# /tmp/ipykernel_200/2651519125.py:1: UserWarning: Parsing '25-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   table['DATE'] = pd.to_datetime(table['DATE'])
# /tmp/ipykernel_200/2651519125.py:1: UserWarning: Parsing '17-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   table['DATE'] = pd.to_datetime(table['DATE'])
# /tmp/ipykernel_200/2651519125.py:1: UserWarning: Parsing '16-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   table['DATE'] = pd.to_datetime(table['DATE'])
# /tmp/ipykernel_200/2651519125.py:1: UserWarning: Parsing '16-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   table['DATE'] = pd.to_datetime(table['DATE'])
# /tmp/ipykernel_200/2651519125.py:1: UserWarning: Parsing '31-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   table['DATE'] = pd.to_datetime(table['DATE'])
# /tmp/ipykernel_200/2651519125.py:1: UserWarning: Parsing '24-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   table['DATE'] = pd.to_datetime(table['DATE'])
# /tmp/ipykernel_200/2651519125.py:1: UserWarning: Parsing '20-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   table['DATE'] = pd.to_datetime(table['DATE'])
# /tmp/ipykernel_200/2651519125.py:1: UserWarning: Parsing '30-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   table['DATE'] = pd.to_datetime(table['DATE'])
# /tmp/ipykernel_200/2651519125.py:1: UserWarning: Parsing '29-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   table['DATE'] = pd.to_datetime(table['DATE'])
# /tmp/ipykernel_200/2651519125.py:1: UserWarning: Parsing '25-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   table['DATE'] = pd.to_datetime(table['DATE'])
# /tmp/ipykernel_200/2651519125.py:1: UserWarning: Parsing '22-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   table['DATE'] = pd.to_datetime(table['DATE'])
# /tmp/ipykernel_200/2651519125.py:1: UserWarning: Parsing '20-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   table['DATE'] = pd.to_datetime(table['DATE'])
# /tmp/ipykernel_200/2651519125.py:1: UserWarning: Parsing '18-10-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   table['DATE'] = pd.to_datetime(table['DATE'])

# %%
table.drop(['date', 'date_split', 'D','M','Y'], axis=1, inplace=True)

# %%
table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TITLE   50 non-null     object
#  1   DETAIL  50 non-null     object
#  2   DATE    50 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), object(2)
# memory usage: 1.3+ KB

# %%
table
# Out:
#                                                 TITLE  \
# 0   Leslie Jordan เสียชีวิตจากอุบัติเหตุทางรถยนต์ด...
# 1   ยูเครนเผย หลายเมืองที่ยึดคืนได้เสียหายหนัก ขณะ...
# 2   เปาตี๋-ฑีธิชัย นวลจันทร์ อดีตผู้ตัดสินฟีฟ่าเสี...
# 3   กทม. เพิ่มไฟกะพริบ-นกหวีด ติดตัวพนักงานกวาดถนน...
# 4   ชัชชาติ ตั้งกรรมการสอบ กรณีอุบัติเหตุบันไดเลื่...
# 5   ชัชชาติมอบหมาย รองผู้ว่าฯ วิศณุ สอบอุบัติเหตุค...
# 6   ตุรกีเกิดอุบัติเหตุบนท้องถนนหลายจุด รถบัส-รถบร...
# 7   ‘ชัชชาติ’ ลงพื้นที่ตรวจสอบอุบัติเหตุ บันได BTS...
# 8   ตร. เผย อุบัติเหตุ BTS สุรศักดิ์ เหตุเกิดจากเบ...
# 9   อนุทินบอก อยู่ในบัญชีนายกฯ มา 4 ปีแล้ว หากมีอุ...
# 10  ครอบครัวยืนยัน ปานเพชร ผดุงชัยมวยไทยยิม นักมวย...
# 11  สำรวจอุบัติเหตุทางอากาศของกองทัพ-ตำรวจ ย้อนหลั...
# 12  เกิดอุบัติเหตุป้ายล้มทับแฟนบอล ก่อนการแข่งขันฟ...
# 13  ‘Halo’ ช่วยชีวิต โจวกวนอวี่ หลังประสบอุบัติเหต...
# 14  อเมริกาเผยอัตราการเกิดอุบัติเหตุของรถยนต์ขับเค...
# 15  เลขาฯ มูลนิธิเมาไม่ขับ ห่วงเมากัญชาแล้วขับรถ อ...
# 16  ชมคลิป: สดจากโค้งถนนรัชดา ผู้ว่าฯ ‘ชัชชาติ’ ลง...
# 17  ชัชชาติ ลงตรวจสอบโค้ง 100 ศพ พิจารณาปรับลดความ...
# 18  เครือข่ายเหยื่อผู้สูญเสียจากอุบัติเหตุฯ​ ยื่นห...
# 19  ‘มาดามแป้ง’ อยู่เวียดนามร่วมศึกซีเกมส์ต่อ หลัง...
# 20  ส.ว. วันชัย ชี้ อุบัติเหตุทางการเมืองเกิดขึ้นไ...
# 21  ส.ว. วันชัย มองเกิดอุบัติเหตุทางการเมืองกับประ...
# 22  ประชุม ครม. ท่ามกลางกระแสข่าวนายกฯ สำรอง หากปร...
# 23  สุชัชวีร์ จัดวงแลกเปลี่ยนความเห็นกับกลุ่มมอเตอ...
# 24  ตำรวจแถลงปิดคดี ‘แตงโม นิดา’ สรุปเป็นอุบัติเหต...
# 25  ห่วงช่วงปิดเทอมใหญ่ เด็กเกิดอุบัติเหตุจมน้ำ ขอ...
# 26  กสร. เตือนนายจ้างกิจการขนส่งช่วงสงกรานต์ ห้ามใ...
# 27  สสส. เปิดรายงานปี 63 เผยอุบัติเหตุทางถนนคร่าชี...
# 28  ดรุณวรรณ แจงเหตุ ‘สุชัชวีร์’ ข้อเท้าแพลงระหว่า...
# 29  สุชัชวีร์ขาพลิกขณะลงพื้นที่เขตคันนายาว บอกอุบั...
# 30  วางดอกไม้อาลัยแตงโม ผบ.ตร. เผย พยานหลักฐานยังช...
# 31  พ่อแม่หมอกระต่ายเข้าพบนายกฯ หารือแนวทางป้องกัน...
# 32  แม่แตงโมเตรียมให้ทนายตรวจสอบ ปมผลประโยชน์จากปร...
# 33  วิโรจน์ลงพื้นที่เกิดเหตุนั่งร้านถล่ม จี้ กทม. ...
# 34  แม่หมอกระต่าย ร้อง กมธ.กฎหมาย สอบข้อเท็จจริงปม...
# 35  สำรวจทางม้าลายสามมิติที่จุฬาฯ หลังโลกออนไลน์แช...
# 36  ส่องสถานการณ์อุบัติเหตุทางถนนของ ‘คนเดินเท้า’ ...
# 37  วิโรจน์ลงพื้นที่ครั้งแรกหลังเปิดตัวเป็นแคนดิเด...
# 38  ย้อนดูข้อมูล ‘อุบัติเหตุทางถนน’ ตลอดปี 2564-ปั...
# 39  Gaspard Ulliel นักแสดงชาวฝรั่งเศสเสียชีวิตในวั...
# 40  วงการลูกหนังตุรกีเศร้า นักเตะดีกรีทีมชาติประสบ...
# 41  Tesla เตรียมเรียกคืนรถรุ่น Model 3 และ Model S...
# 42  ปภ. รายงานอุบัติเหตุเฉพาะวันสิ้นปีรวม 555 ครั้...
# 43  ประยุทธ์ฝากประชาชนรักษาวินัยจราจร สวมหมวกกันน็...
# 44  SCB Protect ใจดี แจกฟรีประกันอุบัติเหตุสำหรับเ...
# 45  รัฐมอบประกันภัยอุบัติเหตุปีใหม่ เบี้ย 10 บาท ค...
# 46  สสส. และเครือข่าย จัดเสวนา ห่วงปัญหาสุราทำอุบั...
# 47  ไทเกอร์-ชาร์ลี วูดส์ ได้อันดับที่ 2 ศึก PNC Ch...
# 48  ฌอน ไวนุย นักรักบี้นิวซีแลนด์วัย 25 ปีจากสโมสร...
# 49  SCB Protect จับมือ DBANK เปิดขายประกันอุบัติเห...
#
#                                                DETAIL       DATE
# 0   เมื่อวันจันทร์ที่ผ่านมา (24 ตุลาคม) เกิดข่าวที... 2022-10-25
# 1   ประธานาธิบดี โวโลดิเมียร์ เซเลนสกี ของยูเครน เ... 2022-09-15
# 2   เมื่อคืนวันที่ 2 กันยายนที่ผ่านมา มีรายงานว่า ... 2022-03-09
# 3   วานนี้ (24 สิงหาคม) ที่เขตจตุจักร พญ.วันทนีย์ ... 2022-08-25
# 4   วันนี้ (22 สิงหาคม) ที่ห้องประชุมและวางแผน War... 2022-08-22
# 5   วันนี้ (21 สิงหาคม) ชัชชาติ สิทธิพันธุ์ ผู้ว่า... 2022-08-21
# 6   วานนี้ (20 สิงหาคม) สำนักข่าวต่างประเทศรายงาน ... 2022-08-21
# 7   วันนี้ (20 สิงหาคม) เมื่อเวลาประมาณ 21.35 น. ช... 2022-08-21
# 8   วันนี้ (20 สิงหาคม) เมื่อเวลา 18.56 น. ร.ต.อ. ... 2022-08-21
# 9   วันนี้ (17 สิงหาคม) อนุทิน ชาญวีรกูล รองนายกรั... 2022-08-17
# 10  วันนี้ (23 กรกฎาคม) ครอบครัวของ ปานเพชร ผดุงชั... 2022-07-24
# 11  เมื่อวันที่ 15 กรกฎาคม เกิดเหตุเฮลิคอปเตอร์แบล... 2022-07-20
# 12  ความเคลื่อนไหวก่อนศึกฟุตบอลกระชับมิตรนัดประวัต... 2022-12-07
# 13  การแข่งขันรถแข่งฟอร์มูลาวัน (F1) รอดพ้นจากวันแ... 2022-04-07
# 14  เป็นครั้งแรกที่รัฐบาลสหรัฐอเมริกาเผยแพร่รายงาน... 2022-06-28
# 15  วันนี้ (11 มิถุนายน) นพ.แท้จริง ศิริพานิช เลขา... 2022-11-06
# 16  สดจากโค้งถนนรัชดา ผู้ว่าฯ 'ชัชชาติ' ลงพื้นที่ต... 2022-03-06
# 17  วันนี้ (3 มิถุนายน) ที่บริเวณหน้าที่ทำการพรรคพ... 2022-03-06
# 18  วันนี้ (2 มิถุนายน) ประศม สุขแสวง ในฐานะประธาน... 2022-02-06
# 19  วันนี้ (17 พฤษภาคม) หลังจากที่มีรายงานจากกรุงฮ... 2022-05-17
# 20  วันนี้ (8 พฤษภาคม) วันชัย สอนศิริ สมาชิกวุฒิสภ... 2022-08-05
# 21  วันนี้ (4 พฤษภาคม)​​ วันชัย สอนศิริ สมาชิกวุฒิ... 2022-04-05
# 22  วันนี้ (3 พฤษภาคม) ที่ทำเนียบรัฐบาล พล.อ. ประย... 2022-03-05
# 23  วันนี้ (2 พฤษภาคม) สุชัชวีร์ สุวรรณสวัสดิ์ ผู้... 2022-02-05
# 24  วันนี้ (26 เมษายน) ที่กองบัญชาการตำรวจภูธรภาค ... 2022-04-26
# 25  วันนี้ (21 เมษายน) ธนกร วังบุญคงชนะ โฆษกประจำส... 2022-04-21
# 26  วันนี้ (4 เมษายน) นิยม สองแก้ว อธิบดีกรมสวัสดิ... 2022-04-04
# 27  วันนี้ (25 มีนาคม) นพ.วิทยา ชาติบัญชาชัย ประธา... 2022-03-25
# 28  จากกรณีการลงพื้นที่ของ ศ.ดร.สุชัชวีร์ สุวรรณสว... 2022-03-17
# 29  วันนี้ (16 มีนาคม) ศ.ดร.สุชัชวีร์ สุวรรณสวัสดิ... 2022-03-16
# 30  วันนี้ (6 มีนาคม) บรรยากาศที่ท่าเรือพิบูลสงครา... 2022-06-03
# 31  วันนี้ (4 มีนาคม) นพ.แท้จริง ศิริพานิช เลขาธิก... 2022-04-03
# 32  วันนี้ (2 มีนาคม) พนิดา ศิระยุทธโยธิน แม่ของ แ... 2022-02-03
# 33  วันนี้ (16 กุมภาพันธ์) วิโรจน์ ลักขณาอดิศร ว่า... 2022-02-16
# 34  วันที่ (3 กุมภาพันธ์) วิสิทธิ์ พิทยาภรณ์ รองปร... 2022-03-02
# 35  เกิดกระแสในโลกออนไลน์หลังมีการแชร์ภาพ ‘ทางม้าล... 2022-01-02
# 36  เหตุการณ์ที่ ส.ต.ต. นรวิชญ์ บัวดก ผบ.หมู่ กองร... 2022-01-31
# 37  วันนี้ (24 มกราคม) ที่บริเวณหน้าโรงพยาบาลสถาบั... 2022-01-24
# 38  สืบเนื่องจากอุบัติเหตุรถจักรยานยนต์บิ๊กไบค์ชน ... 2022-01-24
# 39  Gaspard Ulliel (กัสปาร์ อุลลิแอล) นักแสดงชื่อด... 2022-01-20
# 40  วันนี้ (11 มกราคม) ข่าวเศร้าของวงการลูกหนังตุร... 2022-11-01
# 41  Tesla เตรียมเรียกคืนรถยนต์ประมาณ 475,000 คันใน... 2022-02-01
# 42  วันนี้ (1 มกราคม) กรมป้องกันและบรรเทาสาธารณภัย... 2022-01-01
# 43  วันนี้ (30 ธันวาคม) ธนกร วังบุญคงชนะ โฆษกประจำ... 2021-12-30
# 44  ปรมาศิริ มโนลม้าย รองผู้จัดการใหญ่อาวุโส ประธา... 2021-12-29
# 45  วันนี้ (25 ธันวาคม) รัชดา ธนาดิเรก รองโฆษกประจ... 2021-12-25
# 46  เมื่อวันที่ 20 ธันวาคมที่ผ่านมา มูลนิธิหญิงชาย... 2021-12-22
# 47  ไทเกอร์ วูดส์ อดีตโปรกอล์ฟมือหนึ่งของโลก กลับม... 2021-12-20
# 48  วันนี้ (18 ตุลาคม) ฌอน ไวนุย นักกีฬารักบี้ทีม ... 2021-10-18
# 49  ปรมาศิริ มโนลม้าย รองผู้จัดการใหญ่อาวุโส ประธา... 2021-04-10

# %%
table.to_csv(r'week04.csv',index=False,encoding='utf-8')

# %%
from dsmlibrary.datanode import DataNode

# %%
dir_raw_id = 64

# %%
datanode = DataNode()
# Out:
# Init DataNode sucessful!

# %%
datanode.upload_file(directory_id=dir_raw_id, file_path='week04.csv')
# Out:
#   0%|          | 0.00/60.7k [00:00<?, ?B/s]
# {'id': 785,
#  'msg': 'file week04.csv create sucessful',
#  'path': 'suphawadi/DSI310-12/rawData/week04.csv',
#  'uploaded': True}
